# %% [markdown]
# # Set-up

# %%
import os
import pandas as pd
import numpy as np
from mygene import MyGeneInfo
import re
import requests
import pyranges as pr

# %%
# Example — change this to the full URL of the GTF file
url = "https://api.data.igvf.org/reference-files/IGVFFI9573KOZR/@@download/IGVFFI9573KOZR.gtf.gz"
out_path = "/cellar/users/aklie/data/datasets/tf_perturb_seq/ref/IGVFFI9573KOZR.gtf.gz"

# Stream download to avoid memory issues, only if doesn't already exist
if not os.path.exists(out_path):
    print("Downloading", url)
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(out_path, "wb") as f:
            for chunk in r.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
elif os.path.getsize(out_path) > 0:
    print("File already exists and is non-empty, skipping download.")
else:
    print("File exists but is empty, re-downloading.")
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(out_path, "wb") as f:
            for chunk in r.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)

print("Downloaded to", out_path)
# Out:
# File already exists and is non-empty, skipping download.
# Downloaded to /cellar/users/aklie/data/datasets/tf_perturb_seq/ref/IGVFFI9573KOZR.gtf.gz

# %%
# Filter to just gene-level annotations
gtf_pr = pr.read_gtf(out_path)
genes_pr = gtf_pr[(gtf_pr.Feature == "gene") & (gtf_pr.gene_type == "protein_coding")]
genes_pr
# Out:
# /cellar/users/aklie/opt/miniconda3/envs/scverse-lite-py39/lib/python3.9/site-packages/pyranges/methods/init.py:45: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   return {k: v for k, v in df.groupby(grpby_key)}
# +--------------+------------+------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature    | Start     | End       | +21   |
# | (category)   | (object)   | (object)   | (int64)   | (int64)   | ...   |
# |--------------+------------+------------+-----------+-----------+-------|
# | chr1         | HAVANA     | gene       | 65418     | 71585     | ...   |
# | chr1         | HAVANA     | gene       | 923922    | 944575    | ...   |
# | chr1         | HAVANA     | gene       | 960583    | 965719    | ...   |
# | chr1         | HAVANA     | gene       | 966481    | 975865    | ...   |
# | ...          | ...        | ...        | ...       | ...       | ...   |
# | chrY         | HAVANA     | gene       | 23129354  | 23199010  | ...   |
# | chrY         | HAVANA     | gene       | 24045228  | 24048019  | ...   |
# | chrY         | HAVANA     | gene       | 24763068  | 24813492  | ...   |
# | chrY         | HAVANA     | gene       | 25030900  | 25062548  | ...   |
# +--------------+------------+------------+-----------+-----------+-------+
# Stranded PyRanges object has 22,181 rows and 26 columns from 235 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 21 hidden columns: Score, Strand, Frame, gene_id, gene_type, gene_name, level, ... (+ 14 more.)

# %%
# --- Define promoter coordinates (2kb upstream of TSS) ---
genes_df = genes_pr.df.copy()

# Compute start and end carefully depending on strand
promoters_df = pd.DataFrame({
    "Chromosome": genes_df["Chromosome"],
    "Strand": genes_df["Strand"],
    "gene_id": genes_df["gene_id"],
    "gene_name": genes_df["gene_name"],
})

# Compute Start and End for promoters
promoters_df["Start"] = promoters_df.apply(
    lambda x: max(0, genes_df.loc[x.name, "Start"] - 2000)
    if x.Strand == "+"
    else genes_df.loc[x.name, "End"],
    axis=1,
)
promoters_df["End"] = promoters_df.apply(
    lambda x: genes_df.loc[x.name, "Start"]
    if x.Strand == "+"
    else genes_df.loc[x.name, "End"] + 2000,
    axis=1,
)

# Convert to integers
promoters_df[["Start", "End"]] = promoters_df[["Start", "End"]].astype(int)

# Check that it looks correct
promoters_pr = pr.PyRanges(promoters_df)
promoters_pr
# Out:
# /cellar/users/aklie/opt/miniconda3/envs/scverse-lite-py39/lib/python3.9/site-packages/pyranges/methods/init.py:45: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   return {k: v for k, v in df.groupby(grpby_key)}
# +--------------+--------------+--------------------+-------------+-------+
# | Chromosome   | Strand       | gene_id            | gene_name   | +2    |
# | (category)   | (category)   | (object)           | (object)    | ...   |
# |--------------+--------------+--------------------+-------------+-------|
# | chr1         | +            | ENSG00000186092.7  | OR4F5       | ...   |
# | chr1         | +            | ENSG00000187634.13 | SAMD11      | ...   |
# | chr1         | +            | ENSG00000187961.15 | KLHL17      | ...   |
# | chr1         | +            | ENSG00000187583.11 | PLEKHN1     | ...   |
# | ...          | ...          | ...                | ...         | ...   |
# | chrY         | -            | ENSG00000188120.16 | DAZ1        | ...   |
# | chrY         | -            | ENSG00000172352.5  | CDY1B       | ...   |
# | chrY         | -            | ENSG00000187191.16 | DAZ3        | ...   |
# | chrY         | -            | ENSG00000185894.8  | BPY2C       | ...   |
# +--------------+--------------+--------------------+-------------+-------+
# Unstranded PyRanges object has 22,181 rows and 6 columns from 235 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.
# 2 hidden columns: Start, End

# %% [markdown]
# # Load reference metadata

# %% [markdown]
# ## Reference TF guides

# %%
path_ref_tf_metadata = "/cellar/users/aklie/data/datasets/tf_perturb_seq/ref/target_genes.tsv"
spacer_cols = ['Set A, Photospacer 1', 'Set A, Photospacer 2', 'Set B, Photospacer 3', 'Set B, Photospacer 4', 'Set C, Photospacer 5', 'Set C, Photospacer 6']
ref_tf = pd.read_csv(path_ref_tf_metadata, sep="\t")
ref_tf["Gene"] = ref_tf["Gene"].ffill()
for col in spacer_cols:
    ref_tf[col] = ref_tf[col].str.upper()

# Define mapping between sets, promoter columns, and photospacer columns
set_map = {
    "A": ("Set A, promoter ID", ["Set A, Photospacer 1", "Set A, Photospacer 2"]),
    "B": ("Set B, promoter ID", ["Set B, Photospacer 3", "Set B, Photospacer 4"]),
    "C": ("Set C, promoter ID", ["Set C, Photospacer 5", "Set C, Photospacer 6"]),
}

# Collect rows
rows = []
for _, row in ref_tf.iterrows():
    gene = row["Gene"]
    for set_name, (prom_col, spacer_cols) in set_map.items():
        promoter_id = row[prom_col]
        for spacer_col in spacer_cols:
            spacer_seq = row[spacer_col]
            if pd.notna(spacer_seq):
                # Extract photospacer number from column name
                match = re.search(r"Photospacer (\d+)", spacer_col)
                spacer_num = int(match.group(1)) if match else None
                rows.append({
                    "Gene": gene,
                    "promoter_ID": promoter_id,
                    "Set": set_name,
                    "Photospacer": spacer_seq,
                    "Photospacer_number": spacer_num,
                })

# Create the long df
ref_tf_long = pd.DataFrame(rows)[["Gene", "promoter_ID", "Set", "Photospacer", "Photospacer_number"]]

# Make a unique guide ID based on promoter_ID#Set_{Set}#Photospacer_{Photospacer_number}
ref_tf_long["guide_id"] = ref_tf_long.apply(lambda x: f"{x['promoter_ID']}#Set_{x['Set']}#Photospacer_{x['Photospacer_number']}", axis=1)
ref_tf_long.head()
# Out:
#    Gene              promoter_ID Set           Photospacer  \
# 0  AATF  AATF_-_35306286.23-P1P2   A  GAGTGGCCGGTCCAGAGCTG
# 1  AATF  AATF_-_35306286.23-P1P2   A  GGGATCAAGGCGAGAGGATC
# 2  AATF  AATF_-_35306351.23-P1P2   B  GAAGGCGAGAGGATCCGGCA
# 3  AATF  AATF_-_35306351.23-P1P2   B  GGGAATCGGATCAAGGCGAG
# 4  AATF  AATF_-_35306333.23-P1P2   C  GGAGTCGGGGAATCGGATCA
#
#    Photospacer_number                                     guide_id
# 0                   1  AATF_-_35306286.23-P1P2#Set_A#Photospacer_1
# 1                   2  AATF_-_35306286.23-P1P2#Set_A#Photospacer_2
# 2                   3  AATF_-_35306351.23-P1P2#Set_B#Photospacer_3
# 3                   4  AATF_-_35306351.23-P1P2#Set_B#Photospacer_4
# 4                   5  AATF_-_35306333.23-P1P2#Set_C#Photospacer_5

# %% [markdown]
# ## Reference positive controls

# %%
def clean_gene_and_make_guide(x):
    x = x.strip()
    
    # --- Remove parentheses in gene names like "CD29 (ITGB1)" ---
    base = re.sub(r"\s*\([^)]*\)", "", x).strip()
    
    # --- Handle sgRNA naming ---
    if "sgRNA" in x:
        base_gene = x.split("sgRNA")[0].strip()
        suffix = x.split("sgRNA")[-1].strip().lower()
        if suffix == "main":
            guide_id = f"{base_gene}#A"
        elif suffix in ["a", "b", "c"]:
            guide_id = f"{base_gene}#{suffix.upper()}"
        else:
            guide_id = f"{base_gene}#A"
        return pd.Series([base_gene, guide_id])
    
    # --- Handle "strong"/"weak" ---
    if re.search(r"\bstrong\b|\bweak\b", x, re.IGNORECASE):
        base_gene = re.sub(r"\s*(strong|weak)\s*", "", base, flags=re.IGNORECASE)
        strength = "strong" if "strong" in x.lower() else "weak"
        guide_id = f"{base_gene}#{strength}"
        return pd.Series([base_gene, guide_id])
    
    # --- Default case: use cleaned base name ---
    return pd.Series([base, f"{base}#A"])

# Load reference 
path_ref_pc_metadata = "/cellar/users/aklie/data/datasets/tf_perturb_seq/ref/positive_controls.tsv"
ref_pcs = pd.read_csv(path_ref_pc_metadata, sep="\t")
ref_pcs = ref_pcs.rename(columns={"Photospacer (represent 10 times)": "Photospacer"})
ref_pcs[["Gene", "guide_id"]] = ref_pcs["Gene"].apply(clean_gene_and_make_guide)
ref_pcs.head()
# Out:
#     Gene           Photospacer  \
# 0   CD81  GGAGAGCGAGCGCGCAACGG
# 1   CD81  GGAGAGCCAGCGCGCAACGG
# 2  CD151  GCCGGACTCGGACGCGTGGT
# 3  CD151  GCCGCTCGGCCGAGCTGTCG
# 4   CD55  GCTGCGACTCGGCGGAGTCC
#
#                                            Reference      guide_id
# 0  Horlbeck et al. 2016 "Compact and highly activ...   CD81#strong
# 1  Jost et al. 2020 "Titrating gene expression us...     CD81#weak
# 2  Horlbeck et al. 2016 "Compact and highly activ...  CD151#strong
# 3  Horlbeck et al. 2016 "Compact and highly activ...    CD151#weak
# 4  Horlbeck et al. 2016 "Compact and highly activ...   CD55#strong

# %% [markdown]
# ## Reference non-targeting controls

# %%
path_ref_nt_metadata = "/cellar/users/aklie/data/datasets/tf_perturb_seq/ref/non_targeting.tsv"
ref_nt = pd.read_csv(path_ref_nt_metadata, sep="\t")
ref_nt = ref_nt.rename(columns={"Unnamed: 0": "guide_id", "Photospacer (same for all 3 sets)": "Photospacer"})
ref_nt["Gene"] = "non-targeting"
ref_nt.head()
# Out:
#               guide_id           Photospacer           Gene
# 0  non-targeting_00642  GGAGTTAAGGCCTCGTCTAG  non-targeting
# 1  non-targeting_00718  GTCCCAGGCTCTCCACTATG  non-targeting
# 2  non-targeting_03631  GGACGCGTCTGCAAGAACGT  non-targeting
# 3  non-targeting_03705  GGGCATGGACCCGCGGCACG  non-targeting
# 4  non-targeting_01469  GCGTCCGAGGTACTGAATAA  non-targeting

# %% [markdown]
# ## Reference negative controls (targeting)

# %%
# ---------- 1. Base reference ----------
path_ref_nc_metadata = "/cellar/users/aklie/data/datasets/tf_perturb_seq/ref/negative_controls.tsv"
ref_nc = pd.read_csv(path_ref_nc_metadata, sep="\t")

# Standardize case
spacer_cols = [c for c in ref_nc.columns if c.startswith("Photospacer")]
for col in spacer_cols:
    ref_nc[col] = ref_nc[col].str.upper()

# Melt to long format
ref_nc_long = ref_nc.melt(
    id_vars=["Gene"],
    value_vars=spacer_cols,
    var_name="Photospacer_label",
    value_name="Photospacer"
)
ref_nc_long["Photospacer_number"] = ref_nc_long["Photospacer_label"].str.extract(r"(\d+)").astype(int)
ref_nc_long["guide_id"] = ref_nc_long.apply(
    lambda x: f"{x['Gene']}#Set_A#Photospacer_{x['Photospacer_number']}", axis=1
)
ref_nc_long = ref_nc_long[["Gene", "Photospacer", "Photospacer_number", "guide_id"]]

# ---------- 2. Single-protospacer negatives ----------
path_simple_nc = "/cellar/users/aklie/data/datasets/tf_perturb_seq/scratch/2025_10_05/2025_10_05_negative_controls.tsv"
ref_nc_single = pd.read_csv(path_simple_nc, sep="\t")

# Normalize column names and create unified structure
ref_nc_single = (
    ref_nc_single.rename(columns={"gene": "Gene", "protospacer_A": "Photospacer"})
    .assign(Photospacer_number=1)
)
ref_nc_single["Photospacer"] = ref_nc_single["Photospacer"].str.upper()
ref_nc_single["guide_id"] = ref_nc_single.apply(
    lambda x: f"{x['Gene']}#Set_A#Photospacer_{x['Photospacer_number']}", axis=1
)
ref_nc_single = ref_nc_single[["Gene", "Photospacer", "Photospacer_number", "guide_id"]]

# ---------- 3. Multi-set negatives ----------
path_more_nc = "/cellar/users/aklie/data/datasets/tf_perturb_seq/scratch/2025_10_05/2025_10_05_more_negative_controls.tsv"
ref_nc_multi = pd.read_csv(path_more_nc, sep="\t")

# Identify photospacer columns automatically
photospacer_cols = [c for c in ref_nc_multi.columns if "Photospacer" in c]

# Melt to long format
ref_nc_multi_long = ref_nc_multi.melt(
    id_vars=["Label"], value_vars=photospacer_cols,
    var_name="Photospacer_label", value_name="Photospacer"
)
ref_nc_multi_long["Gene"] = ref_nc_multi_long["Label"]
ref_nc_multi_long["Photospacer"] = ref_nc_multi_long["Photospacer"].str.upper()

# Extract number and set info
ref_nc_multi_long["Photospacer_number"] = ref_nc_multi_long["Photospacer_label"].str.extract(r"(\d+)").astype(int)
ref_nc_multi_long["Set"] = ref_nc_multi_long["Photospacer_label"].str.extract(r"(Set [A-Z])")

# Create guide_id harmonized with the same pattern
ref_nc_multi_long["guide_id"] = ref_nc_multi_long.apply(
    lambda x: f"{x['Gene']}#{x['Set'].replace(' ', '_')}#Photospacer_{x['Photospacer_number']}", axis=1
)

ref_nc_multi_long = ref_nc_multi_long[["Gene", "Photospacer", "Photospacer_number", "guide_id"]]

# ---------- 4. Concatenate & finalize ----------
ref_nc_all = pd.concat([ref_nc_long, ref_nc_single, ref_nc_multi_long], ignore_index=True)
ref_nc_all = ref_nc_all.drop_duplicates().sort_values(["Gene", "Photospacer_number"]).reset_index(drop=True)

ref_nc_all.head()
# Out:
#      Gene           Photospacer  Photospacer_number  \
# 0  OR10A2  GTTCCTGTAGCTATAAGTGT                   1
# 1  OR10A3  GTTCCTCCTGAACCTATCTG                   1
# 2  OR10A4  GGCCTGAAGCTCAGTGGACA                   1
# 3  OR10A5  GCTGGAGAGAGATTCTTGAT                   1
# 4  OR10A6  GGGTCACCAGATAAATAACC                   1
#
#                      guide_id
# 0  OR10A2#Set_A#Photospacer_1
# 1  OR10A3#Set_A#Photospacer_1
# 2  OR10A4#Set_A#Photospacer_1
# 3  OR10A5#Set_A#Photospacer_1
# 4  OR10A6#Set_A#Photospacer_1

# %% [markdown]
# # Load guide metadata

# %%
path_guide_metadata = "/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/downloads/IGVFFI5765HMZH.tsv"
guide_metadata = pd.read_csv(path_guide_metadata)
guide_metadata["Photospacer"] = "G" + guide_metadata["spacer"].str.upper()
print(f"{len(guide_metadata)} total guides")
guide_metadata.head()
# Out:
# 415 total guides
#                       guide_id               spacer  targeting       type  \
# 0  chr5:132963540-132963558(+)  GGGCGGGTTAACGAAGACC       True  targeting
# 1  chr5:132963579-132963597(-)  TCGCCGCCGCCAGCGGACG       True  targeting
# 2  chr5:132963567-132963585(+)  GGATCCCCGCCCCGTCCGC       True  targeting
# 3  chr5:132963620-132963638(+)  AGGGCTGTGACTGACGCAG       True  targeting
# 4  chr5:132963570-132963588(+)  TCCCCGCCCCGTCCGCTGG       True  targeting
#
#   guide_chr  guide_start  guide_end strand  PAM intended_target_name  \
# 0      chr5    132963540  132963540      +  NGG      ENSG00000072364
# 1      chr5    132963579  132963579      -  NGG      ENSG00000072364
# 2      chr5    132963567  132963567      +  NGG      ENSG00000072364
# 3      chr5    132963620  132963620      +  NGG      ENSG00000072364
# 4      chr5    132963570  132963570      +  NGG      ENSG00000072364
#
#   intended_target_chr  intended_target_start  intended_target_end  \
# 0                chr5              132963540            132963638
# 1                chr5              132963540            132963638
# 2                chr5              132963540            132963638
# 3                chr5              132963540            132963638
# 4                chr5              132963540            132963638
#
#             Photospacer
# 0  GGGGCGGGTTAACGAAGACC
# 1  GTCGCCGCCGCCAGCGGACG
# 2  GGGATCCCCGCCCCGTCCGC
# 3  GAGGGCTGTGACTGACGCAG
# 4  GTCCCCGCCCCGTCCGCTGG

# %% [markdown]
# ## Fix missing target names

# %%
len(guide_metadata[guide_metadata["intended_target_name"].isna()])
# Out:
# 42

# %%
# Convert guides to PyRanges
guides_pr = pr.PyRanges(
    df=guide_metadata.rename(columns={
        'intended_target_chr': 'Chromosome',
        'intended_target_start': 'Start',
        'intended_target_end': 'End',
        'guide_id': 'guide_id'
    })
)

# Find overlaps with gene regions
overlaps = guides_pr.join(genes_pr, suffix="_gene")

# Convert to DataFrame
overlaps_df = overlaps.df

# Compute overlap length
overlaps_df["overlap_length"] = (
    overlaps_df[["End", "End_gene"]].min(axis=1)
    - overlaps_df[["Start", "Start_gene"]].max(axis=1)
)

# Keep only the gene with the maximum overlap per guide_id
best_hits = (
    overlaps_df.sort_values("overlap_length", ascending=False)
    .groupby("guide_id", as_index=False)
    .first()
)

# Keep relevant columns
best_hits = best_hits[["guide_id", "gene_id", "gene_name", "overlap_length"]]

# Update gene_name and gene_id with _gtf suffix
best_hits.rename(columns={
    "gene_name": "gene_name_gtf",
    "gene_id": "gene_id_gtf"
}, inplace=True)

# Duplicate guide_ids?
best_hits[best_hits.duplicated(subset=["guide_id"], keep=False)].sort_values("guide_id")
# Out:
# /cellar/users/aklie/opt/miniconda3/envs/scverse-lite-py39/lib/python3.9/site-packages/pyranges/methods/init.py:45: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   return {k: v for k, v in df.groupby(grpby_key)}
# /cellar/users/aklie/opt/miniconda3/envs/scverse-lite-py39/lib/python3.9/site-packages/pyranges/methods/init.py:160: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   empty_removed = df.groupby(["Chromosome", "Strand"])
# join: Strand data from other will be added as strand data to self.
# If this is undesired use the flag apply_strand_suffix=False.
# To turn off the warning set apply_strand_suffix to True or False.
# Empty DataFrame
# Columns: [guide_id, gene_id_gtf, gene_name_gtf, overlap_length]
# Index: []

# %%
# Merge with original df
guide_metadata = guide_metadata.merge(best_hits, on="guide_id", how="left")

# %%
missing_targets = guide_metadata[guide_metadata["intended_target_name"].isna()]
missing_targets["gene_name_gtf"].value_counts()
# Out:
# gene_name_gtf
# POU5F1     12
# SMARCB1    12
# OR2A25      6
# OR2F1       6
# TCF7L1      6
# Name: count, dtype: int64

# %%
# intended_target_name is gene_id for NaN enties
guide_metadata.loc[guide_metadata["intended_target_name"].isna(), "intended_target_name"] = guide_metadata.loc[guide_metadata["intended_target_name"].isna(), "gene_id_gtf"]

# %%
len(guide_metadata[guide_metadata["intended_target_name"].isna()])
# Out:
# 0

# %% [markdown]
# ## Add gene name

# %%
# Initialize MyGeneInfo
mg = MyGeneInfo()

# %%
# Map intended_target_name (Ensembl IDs) to gene names
out = mg.querymany(guide_metadata['intended_target_name'].tolist(), scopes='ensembl.gene', fields='symbol', species='human')
map_df = pd.DataFrame(out)[['query', 'symbol']].rename(columns={'query': 'intended_target_name', 'symbol': 'gene_name_mygene'})
guide_metadata = pd.concat([guide_metadata, map_df["gene_name_mygene"]], axis=1)
guide_metadata.head()
# Out:
# Input sequence provided is already in string format. No operation performed
# Input sequence provided is already in string format. No operation performed
# 50 input query terms found dup hits:	[('ENSG00000072364', 6), ('ENSG00000117713', 6), ('ENSG00000049618', 12), ('ENSG00000143437', 6), ('
# 80 input query terms found no hit:	['ENSSDUG00000003529', 'ENSSDUG00000003529', 'ENSSDUG00000003529', 'ENSSDUG00000003529', 'ENSSDUG000
#                       guide_id               spacer  targeting       type  \
# 0  chr5:132963540-132963558(+)  GGGCGGGTTAACGAAGACC       True  targeting
# 1  chr5:132963579-132963597(-)  TCGCCGCCGCCAGCGGACG       True  targeting
# 2  chr5:132963567-132963585(+)  GGATCCCCGCCCCGTCCGC       True  targeting
# 3  chr5:132963620-132963638(+)  AGGGCTGTGACTGACGCAG       True  targeting
# 4  chr5:132963570-132963588(+)  TCCCCGCCCCGTCCGCTGG       True  targeting
#
#   guide_chr  guide_start  guide_end strand  PAM intended_target_name  \
# 0      chr5    132963540  132963540      +  NGG      ENSG00000072364
# 1      chr5    132963579  132963579      -  NGG      ENSG00000072364
# 2      chr5    132963567  132963567      +  NGG      ENSG00000072364
# 3      chr5    132963620  132963620      +  NGG      ENSG00000072364
# 4      chr5    132963570  132963570      +  NGG      ENSG00000072364
#
#   intended_target_chr  intended_target_start  intended_target_end  \
# 0                chr5              132963540            132963638
# 1                chr5              132963540            132963638
# 2                chr5              132963540            132963638
# 3                chr5              132963540            132963638
# 4                chr5              132963540            132963638
#
#             Photospacer         gene_id_gtf gene_name_gtf  overlap_length  \
# 0  GGGGCGGGTTAACGAAGACC  ENSG00000072364.13          AFF4            94.0
# 1  GTCGCCGCCGCCAGCGGACG  ENSG00000072364.13          AFF4            94.0
# 2  GGGATCCCCGCCCCGTCCGC  ENSG00000072364.13          AFF4            94.0
# 3  GAGGGCTGTGACTGACGCAG  ENSG00000072364.13          AFF4            94.0
# 4  GTCCCCGCCCCGTCCGCTGG  ENSG00000072364.13          AFF4            94.0
#
#   gene_name_mygene
# 0             AFF4
# 1             AFF4
# 2             AFF4
# 3             AFF4
# 4             AFF4

# %%
# How many mismatches between gtf and mygene?
mismatched_gene_name = guide_metadata[(guide_metadata["gene_name_gtf"] != guide_metadata["gene_name_mygene"]) & 
                                     guide_metadata["gene_name_gtf"].notna() & 
                                     guide_metadata["gene_name_mygene"].notna()]
mismatched_gene_name[["guide_id", "intended_target_name", "gene_name_gtf", "gene_name_mygene"]]
# Out:
#                        guide_id intended_target_name    gene_name_gtf  \
# 258  chr18:51030267-51030285(+)      ENSG00000141646  ENSG00000267699
# 261  chr18:51030262-51030280(+)      ENSG00000141646  ENSG00000267699
#
#     gene_name_mygene
# 258            SMAD4
# 261            SMAD4

# %%
# Make new gene_name column
# My gene first
# If mygene is NaN, use gtf
guide_metadata["gene_name"] = guide_metadata.apply(
    lambda x: x["gene_name_mygene"] if pd.notna(x["gene_name_mygene"]) else (x["gene_name_gtf"] if pd.notna(x["gene_name_gtf"]) else x["intended_target_name"]),
    axis=1
)

# %%
guide_metadata["intended_target_name"]
# Out:
# 0      ENSG00000072364
# 1      ENSG00000072364
# 2      ENSG00000072364
# 3      ENSG00000072364
# 4      ENSG00000072364
#             ...
# 410      non-targeting
# 411      non-targeting
# 412      non-targeting
# 413      non-targeting
# 414      non-targeting
# Name: intended_target_name, Length: 415, dtype: object

# %% [markdown]
# # Positive control metadata

# %%
# Grab the positive controls
pc_metadata = guide_metadata[guide_metadata["type"] == "positive control"]
print(f"{len(pc_metadata)} positive control guides")
pc_metadata
# Out:
# 7 positive control guides
#     guide_id               spacer  targeting              type guide_chr  \
# 378     CD81  GAGAGCCAGCGCGCAACGG      False  positive control      chrC
# 379    CD151  CCGGACTCGGACGCGTGGT      False  positive control      chrC
# 380    CD151  CCGCTCGGCCGAGCTGTCG      False  positive control      chrC
# 381     CD55  CTGCGACTCGGCGGAGTCC      False  positive control      chrC
# 382  NGFRAP1  GTTGGAGTTTGCCCTCCTC      False  positive control      chrC
# 383  NGFRAP1  AGGACCGAGAAGAGTGACA      False  positive control      chrC
# 384     TFRC  CTCAGAGCGTCGGGATATC      False  positive control      chrC
#
#      guide_start  guide_end strand  PAM intended_target_name  \
# 378            0          0      +  NGG      ENSG00000110651
# 379            0          0      +  NGG      ENSG00000177697
# 380            0          0      +  NGG      ENSG00000177697
# 381            0          0      +  NGG      ENSG00000196352
# 382            0          0      +  NGG   ENSBTSG00005026991
# 383            0          0      +  NGG   ENSBTSG00005026991
# 384            0          0      +  NGG      ENSG00000072274
#
#     intended_target_chr  intended_target_start  intended_target_end  \
# 378               chrPC                      0                    0
# 379               chrPC                      0                    0
# 380               chrPC                      0                    0
# 381               chrPC                      0                    0
# 382               chrPC                      0                    0
# 383               chrPC                      0                    0
# 384               chrPC                      0                    0
#
#               Photospacer gene_id_gtf gene_name_gtf  overlap_length  \
# 378  GGAGAGCCAGCGCGCAACGG         NaN           NaN             NaN
# 379  GCCGGACTCGGACGCGTGGT         NaN           NaN             NaN
# 380  GCCGCTCGGCCGAGCTGTCG         NaN           NaN             NaN
# 381  GCTGCGACTCGGCGGAGTCC         NaN           NaN             NaN
# 382  GGTTGGAGTTTGCCCTCCTC         NaN           NaN             NaN
# 383  GAGGACCGAGAAGAGTGACA         NaN           NaN             NaN
# 384  GCTCAGAGCGTCGGGATATC         NaN           NaN             NaN
#
#     gene_name_mygene           gene_name
# 378             CD81                CD81
# 379            CD151               CD151
# 380            CD151               CD151
# 381             CD55                CD55
# 382              NaN  ENSBTSG00005026991
# 383              NaN  ENSBTSG00005026991
# 384             TFRC                TFRC

# %%
pc_metadata[pc_metadata.columns[:8]]
# Out:
#     guide_id               spacer  targeting              type guide_chr  \
# 378     CD81  GAGAGCCAGCGCGCAACGG      False  positive control      chrC
# 379    CD151  CCGGACTCGGACGCGTGGT      False  positive control      chrC
# 380    CD151  CCGCTCGGCCGAGCTGTCG      False  positive control      chrC
# 381     CD55  CTGCGACTCGGCGGAGTCC      False  positive control      chrC
# 382  NGFRAP1  GTTGGAGTTTGCCCTCCTC      False  positive control      chrC
# 383  NGFRAP1  AGGACCGAGAAGAGTGACA      False  positive control      chrC
# 384     TFRC  CTCAGAGCGTCGGGATATC      False  positive control      chrC
#
#      guide_start  guide_end strand
# 378            0          0      +
# 379            0          0      +
# 380            0          0      +
# 381            0          0      +
# 382            0          0      +
# 383            0          0      +
# 384            0          0      +

# %%
pc_metadata["in_ref"] = pc_metadata["Photospacer"].isin(ref_pcs["Photospacer"])
# Out:
# /tmp/ipykernel_1267871/380253898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pc_metadata["in_ref"] = pc_metadata["Photospacer"].isin(ref_pcs["Photospacer"])

# %%
pc_metadata[~pc_metadata["in_ref"]]
# Out:
#     guide_id               spacer  targeting              type guide_chr  \
# 382  NGFRAP1  GTTGGAGTTTGCCCTCCTC      False  positive control      chrC
#
#      guide_start  guide_end strand  PAM intended_target_name  \
# 382            0          0      +  NGG   ENSBTSG00005026991
#
#     intended_target_chr  intended_target_start  intended_target_end  \
# 382               chrPC                      0                    0
#
#               Photospacer gene_id_gtf gene_name_gtf  overlap_length  \
# 382  GGTTGGAGTTTGCCCTCCTC         NaN           NaN             NaN
#
#     gene_name_mygene           gene_name  in_ref
# 382              NaN  ENSBTSG00005026991   False

# %%
# Add reference guide_id
pc_metadata = pc_metadata.merge(ref_pcs[["Photospacer", "guide_id"]], on="Photospacer", how="left", suffixes=("", "_ref"))
pc_metadata
# Out:
#   guide_id               spacer  targeting              type guide_chr  \
# 0     CD81  GAGAGCCAGCGCGCAACGG      False  positive control      chrC
# 1    CD151  CCGGACTCGGACGCGTGGT      False  positive control      chrC
# 2    CD151  CCGCTCGGCCGAGCTGTCG      False  positive control      chrC
# 3     CD55  CTGCGACTCGGCGGAGTCC      False  positive control      chrC
# 4  NGFRAP1  GTTGGAGTTTGCCCTCCTC      False  positive control      chrC
# 5  NGFRAP1  AGGACCGAGAAGAGTGACA      False  positive control      chrC
# 6     TFRC  CTCAGAGCGTCGGGATATC      False  positive control      chrC
#
#    guide_start  guide_end strand  PAM intended_target_name  ...  \
# 0            0          0      +  NGG      ENSG00000110651  ...
# 1            0          0      +  NGG      ENSG00000177697  ...
# 2            0          0      +  NGG      ENSG00000177697  ...
# 3            0          0      +  NGG      ENSG00000196352  ...
# 4            0          0      +  NGG   ENSBTSG00005026991  ...
# 5            0          0      +  NGG   ENSBTSG00005026991  ...
# 6            0          0      +  NGG      ENSG00000072274  ...
#
#   intended_target_start  intended_target_end           Photospacer  \
# 0                     0                    0  GGAGAGCCAGCGCGCAACGG
# 1                     0                    0  GCCGGACTCGGACGCGTGGT
# 2                     0                    0  GCCGCTCGGCCGAGCTGTCG
# 3                     0                    0  GCTGCGACTCGGCGGAGTCC
# 4                     0                    0  GGTTGGAGTTTGCCCTCCTC
# 5                     0                    0  GAGGACCGAGAAGAGTGACA
# 6                     0                    0  GCTCAGAGCGTCGGGATATC
#
#   gene_id_gtf gene_name_gtf overlap_length  gene_name_mygene  \
# 0         NaN           NaN            NaN              CD81
# 1         NaN           NaN            NaN             CD151
# 2         NaN           NaN            NaN             CD151
# 3         NaN           NaN            NaN              CD55
# 4         NaN           NaN            NaN               NaN
# 5         NaN           NaN            NaN               NaN
# 6         NaN           NaN            NaN              TFRC
#
#             gene_name in_ref  guide_id_ref
# 0                CD81   True     CD81#weak
# 1               CD151   True  CD151#strong
# 2               CD151   True    CD151#weak
# 3                CD55   True   CD55#strong
# 4  ENSBTSG00005026991  False           NaN
# 5  ENSBTSG00005026991   True     NGFRAP1#A
# 6                TFRC   True        TFRC#A
#
# [7 rows x 21 columns]

# %%
# Make new_guide_id column
# for NGFRAP1	GTTGGAGTTTGCCCTCCTC make this NGFRAP1#B
pc_metadata["new_guide_id"] = pc_metadata.apply(
    lambda x: x["guide_id_ref"] if pd.notna(x["guide_id_ref"]) else f"{x['guide_id']}#B", axis=1
)

# Write out as fasta file
path_out_pc_fasta = "/cellar/users/aklie/data/datasets/tf_perturb_seq/scratch/2025_10_05/positive_control_guides.fasta"
with open(path_out_pc_fasta, "w") as f:
    for _, row in pc_metadata.iterrows():
        if row["new_guide_id"] == "CD81#weak":
            f.write(f">{row['new_guide_id']}\n{ref_pcs[ref_pcs['guide_id'] == 'CD81#strong']['Photospacer'].values[0][1:]}NGG\n")
        elif row["new_guide_id"] == "CD151#weak":
            f.write(f">{row['new_guide_id']}\n{ref_pcs[ref_pcs['guide_id'] == 'CD151#strong']['Photospacer'].values[0][1:]}NGG\n")
        else:
            f.write(f">{row['new_guide_id']}\n{row['spacer']}NGG\n")
print(f"Wrote positive control guides to {path_out_pc_fasta}")
# Out:
# Wrote positive control guides to /cellar/users/aklie/data/datasets/tf_perturb_seq/scratch/2025_10_05/positive_control_guides.fasta

# %%
blat_res = pd.read_csv("/cellar/users/aklie/data/datasets/tf_perturb_seq/scratch/2025_10_05/2025_10_05_BLAT_res.tsv", sep="\t")
blat_res["tStart_adj"] = np.where(blat_res["strand"] == "-", blat_res["tStart"] + 3, blat_res["tStart"])
blat_res["tEnd_adj"] = np.where(blat_res["strand"] == "+", blat_res["tEnd"] - 3, blat_res["tEnd"])
blat_res["match_length"] = blat_res["tEnd_adj"] - blat_res["tStart_adj"] + 1
blat_res["tStrand"] = blat_res["strand"]
blat_res
# Out:
#           query  score  qStart  qEnd  qSize identity  chrom strand     tStart  \
# 0  CD151#strong     21       1    22     22   100.0%  chr11      +     833006
# 1    CD151#weak     21       1    22     22   100.0%  chr11      +     833006
# 2   CD55#strong     21       1    22     22   100.0%   chr1      +  207321714
# 3     CD81#weak     21       1    22     22   100.0%  chr11      +    2377315
# 4     NGFRAP1#A     21       1    22     22   100.0%   chrX      +  103376320
# 5     NGFRAP1#B     21       1    22     22   100.0%   chrX      -  103376258
# 6        TFRC#A     21       1    22     22   100.0%   chr3      -  196082072
#
#         tEnd  span  tStart_adj   tEnd_adj  match_length tStrand
# 0     833027    22      833006     833024            19       +
# 1     833027    22      833006     833024            19       +
# 2  207321735    22   207321714  207321732            19       +
# 3    2377336    22     2377315    2377333            19       +
# 4  103376341    22   103376320  103376338            19       +
# 5  103376279    22   103376261  103376279            19       -
# 6  196082093    22   196082075  196082093            19       -

# %%
# Add in guide_chr, guide_start, guide_end from blat res to pc_metadata
pc_metadata = pc_metadata.merge(
    blat_res[["query", "chrom", "tStart", "tEnd_adj", "tStrand"]],
    left_on="new_guide_id",
    right_on="query",
    how="left"
).rename(columns={
    "chrom": "guide_chr_blat",
    "tStart_adj": "guide_start_blat",
    "tEnd_adj": "guide_end_blat",
    "tStrand": "strand_blat"
}).drop(columns=["query"])
pc_metadata.head()
# Out:
#   guide_id               spacer  targeting              type guide_chr  \
# 0     CD81  GAGAGCCAGCGCGCAACGG      False  positive control      chrC
# 1    CD151  CCGGACTCGGACGCGTGGT      False  positive control      chrC
# 2    CD151  CCGCTCGGCCGAGCTGTCG      False  positive control      chrC
# 3     CD55  CTGCGACTCGGCGGAGTCC      False  positive control      chrC
# 4  NGFRAP1  GTTGGAGTTTGCCCTCCTC      False  positive control      chrC
#
#    guide_start  guide_end strand  PAM intended_target_name  ...  \
# 0            0          0      +  NGG      ENSG00000110651  ...
# 1            0          0      +  NGG      ENSG00000177697  ...
# 2            0          0      +  NGG      ENSG00000177697  ...
# 3            0          0      +  NGG      ENSG00000196352  ...
# 4            0          0      +  NGG   ENSBTSG00005026991  ...
#
#   overlap_length  gene_name_mygene           gene_name in_ref  guide_id_ref  \
# 0            NaN              CD81                CD81   True     CD81#weak
# 1            NaN             CD151               CD151   True  CD151#strong
# 2            NaN             CD151               CD151   True    CD151#weak
# 3            NaN              CD55                CD55   True   CD55#strong
# 4            NaN               NaN  ENSBTSG00005026991  False           NaN
#
#    new_guide_id  guide_chr_blat guide_start_blat guide_end_blat  strand_blat
# 0     CD81#weak           chr11          2377315        2377333            +
# 1  CD151#strong           chr11           833006         833024            +
# 2    CD151#weak           chr11           833006         833024            +
# 3   CD55#strong            chr1        207321714      207321732            +
# 4     NGFRAP1#B            chrX        103376258      103376279            -
#
# [5 rows x 26 columns]

# %%
# Clean up
pc_metadata["targeting"] = True
pc_metadata["type"] = "targeting"
pc_metadata["label"] = "positive_control"
pc_metadata["intended_target_chr"] = pc_metadata["guide_chr_blat"]
pc_metadata["intended_target_start"] = pc_metadata["guide_start_blat"]
pc_metadata["intended_target_end"] = pc_metadata["guide_end_blat"]
pc_metadata.loc[pc_metadata["gene_name"] == "ENSBTSG00005026991", "gene_name"] = "NGFRAP1"
pc_metadata
# Out:
#   guide_id               spacer  targeting       type guide_chr  guide_start  \
# 0     CD81  GAGAGCCAGCGCGCAACGG       True  targeting      chrC            0
# 1    CD151  CCGGACTCGGACGCGTGGT       True  targeting      chrC            0
# 2    CD151  CCGCTCGGCCGAGCTGTCG       True  targeting      chrC            0
# 3     CD55  CTGCGACTCGGCGGAGTCC       True  targeting      chrC            0
# 4  NGFRAP1  GTTGGAGTTTGCCCTCCTC       True  targeting      chrC            0
# 5  NGFRAP1  AGGACCGAGAAGAGTGACA       True  targeting      chrC            0
# 6     TFRC  CTCAGAGCGTCGGGATATC       True  targeting      chrC            0
#
#    guide_end strand  PAM intended_target_name  ... gene_name_mygene  \
# 0          0      +  NGG      ENSG00000110651  ...             CD81
# 1          0      +  NGG      ENSG00000177697  ...            CD151
# 2          0      +  NGG      ENSG00000177697  ...            CD151
# 3          0      +  NGG      ENSG00000196352  ...             CD55
# 4          0      +  NGG   ENSBTSG00005026991  ...              NaN
# 5          0      +  NGG   ENSBTSG00005026991  ...              NaN
# 6          0      +  NGG      ENSG00000072274  ...             TFRC
#
#    gene_name  in_ref  guide_id_ref  new_guide_id guide_chr_blat  \
# 0       CD81    True     CD81#weak     CD81#weak          chr11
# 1      CD151    True  CD151#strong  CD151#strong          chr11
# 2      CD151    True    CD151#weak    CD151#weak          chr11
# 3       CD55    True   CD55#strong   CD55#strong           chr1
# 4    NGFRAP1   False           NaN     NGFRAP1#B           chrX
# 5    NGFRAP1    True     NGFRAP1#A     NGFRAP1#A           chrX
# 6       TFRC    True        TFRC#A        TFRC#A           chr3
#
#    guide_start_blat guide_end_blat strand_blat             label
# 0           2377315        2377333           +  positive_control
# 1            833006         833024           +  positive_control
# 2            833006         833024           +  positive_control
# 3         207321714      207321732           +  positive_control
# 4         103376258      103376279           -  positive_control
# 5         103376320      103376338           +  positive_control
# 6         196082072      196082093           -  positive_control
#
# [7 rows x 27 columns]

# %%
pc_clean_metadata = pc_metadata[["new_guide_id", "spacer", "targeting", "type", 
             "guide_chr_blat", "guide_start_blat", "guide_end_blat", "strand_blat", "PAM", 
             "intended_target_name", "intended_target_chr", "intended_target_start", "intended_target_end", 
             "gene_name", "label"]].rename(columns={"new_guide_id": "guide_id", "guide_chr_blat": "guide_chr",
                                                  "guide_start_blat": "guide_start", "guide_end_blat": "guide_end",
                                                  "strand_blat": "strand"})
pc_clean_metadata
# Out:
#        guide_id               spacer  targeting       type guide_chr  \
# 0     CD81#weak  GAGAGCCAGCGCGCAACGG       True  targeting     chr11
# 1  CD151#strong  CCGGACTCGGACGCGTGGT       True  targeting     chr11
# 2    CD151#weak  CCGCTCGGCCGAGCTGTCG       True  targeting     chr11
# 3   CD55#strong  CTGCGACTCGGCGGAGTCC       True  targeting      chr1
# 4     NGFRAP1#B  GTTGGAGTTTGCCCTCCTC       True  targeting      chrX
# 5     NGFRAP1#A  AGGACCGAGAAGAGTGACA       True  targeting      chrX
# 6        TFRC#A  CTCAGAGCGTCGGGATATC       True  targeting      chr3
#
#    guide_start  guide_end strand  PAM intended_target_name  \
# 0      2377315    2377333      +  NGG      ENSG00000110651
# 1       833006     833024      +  NGG      ENSG00000177697
# 2       833006     833024      +  NGG      ENSG00000177697
# 3    207321714  207321732      +  NGG      ENSG00000196352
# 4    103376258  103376279      -  NGG   ENSBTSG00005026991
# 5    103376320  103376338      +  NGG   ENSBTSG00005026991
# 6    196082072  196082093      -  NGG      ENSG00000072274
#
#   intended_target_chr  intended_target_start  intended_target_end gene_name  \
# 0               chr11                2377315              2377333      CD81
# 1               chr11                 833006               833024     CD151
# 2               chr11                 833006               833024     CD151
# 3                chr1              207321714            207321732      CD55
# 4                chrX              103376258            103376279   NGFRAP1
# 5                chrX              103376320            103376338   NGFRAP1
# 6                chr3              196082072            196082093      TFRC
#
#               label
# 0  positive_control
# 1  positive_control
# 2  positive_control
# 3  positive_control
# 4  positive_control
# 5  positive_control
# 6  positive_control

# %% [markdown]
# # Non-targeting control metadata

# %%
# Grab the non-targeting controls
nt_metadata = guide_metadata[guide_metadata["type"] == "non-targeting"]
nt_metadata
# Out:
#                 guide_id               spacer  targeting           type  \
# 385  non-targeting_00642  GAGTTAAGGCCTCGTCTAG      False  non-targeting
# 386  non-targeting_00718  TCCCAGGCTCTCCACTATG      False  non-targeting
# 387  non-targeting_03631  GACGCGTCTGCAAGAACGT      False  non-targeting
# 388  non-targeting_03705  GGCATGGACCCGCGGCACG      False  non-targeting
# 389  non-targeting_01469  CGTCCGAGGTACTGAATAA      False  non-targeting
# 390  non-targeting_02459  TCTGACTCTCCGTCCACCA      False  non-targeting
# 391  non-targeting_00166  AGCCCCGCCTGGGTACGCG      False  non-targeting
# 392  non-targeting_01967  GGCACCGCCGTTAAAAGTT      False  non-targeting
# 393  non-targeting_02577  CTACAACCGGCGAGCGATA      False  non-targeting
# 394  non-targeting_00954  TAACTGCTACGGCGCCCAA      False  non-targeting
# 395  non-targeting_02829  GGATCAGTGAGGTCGGCCT      False  non-targeting
# 396  non-targeting_03368  GGTTCGAGCCAGAGACCGG      False  non-targeting
# 397  non-targeting_02691  CTATCCTAGACGAAAATCG      False  non-targeting
# 398  non-targeting_01981  CTACCCGGGTAGTGGCGAG      False  non-targeting
# 399  non-targeting_01227  GGTGGCCTGAGCTAGTACA      False  non-targeting
# 400  non-targeting_03783  GAGCTAGGATCGAACGACA      False  non-targeting
# 401  non-targeting_01498  CTTACGAGGGGGCGCTGCT      False  non-targeting
# 402  non-targeting_03484  GGGTGTCGGCAACACCGCG      False  non-targeting
# 403  non-targeting_03306  TGTACGGCCGTATGGAGCT      False  non-targeting
# 404  non-targeting_01779  GGCCCTTGAGGCGGGCCGA      False  non-targeting
# 405  non-targeting_01298  CTAACAAATACATCGGCAG      False  non-targeting
# 406  non-targeting_03347  TATATACGGCGGTCGTATC      False  non-targeting
# 407  non-targeting_02578  GGGCGCCCGGAGACTATCC      False  non-targeting
# 408  non-targeting_00518  ATTGCGCAAGCCAGGTTAC      False  non-targeting
# 409  non-targeting_01136  GTACGCCTGCGGTCGAGTA      False  non-targeting
# 410  non-targeting_03639  GGCCCGCCACGCCGTAACC      False  non-targeting
# 411  non-targeting_02417  GAAAACTGTGCCCCCCTTA      False  non-targeting
# 412  non-targeting_03129  ACCGGCATCAGCCGAGGGG      False  non-targeting
# 413  non-targeting_00550  CCCCGGCGGACAAAACCGG      False  non-targeting
# 414  non-targeting_00013  AGAGGTCGGATACGCTTCC      False  non-targeting
#
#     guide_chr  guide_start  guide_end strand  PAM intended_target_name  \
# 385      chrC            0          0      +  NGG        non-targeting
# 386      chrC            0          0      +  NGG        non-targeting
# 387      chrC            0          0      +  NGG        non-targeting
# 388      chrC            0          0      +  NGG        non-targeting
# 389      chrC            0          0      +  NGG        non-targeting
# 390      chrC            0          0      +  NGG        non-targeting
# 391      chrC            0          0      +  NGG        non-targeting
# 392      chrC            0          0      +  NGG        non-targeting
# 393      chrC            0          0      +  NGG        non-targeting
# 394      chrC            0          0      +  NGG        non-targeting
# 395      chrC            0          0      +  NGG        non-targeting
# 396      chrC            0          0      +  NGG        non-targeting
# 397      chrC            0          0      +  NGG        non-targeting
# 398      chrC            0          0      +  NGG        non-targeting
# 399      chrC            0          0      +  NGG        non-targeting
# 400      chrC            0          0      +  NGG        non-targeting
# 401      chrC            0          0      +  NGG        non-targeting
# 402      chrC            0          0      +  NGG        non-targeting
# 403      chrC            0          0      +  NGG        non-targeting
# 404      chrC            0          0      +  NGG        non-targeting
# 405      chrC            0          0      +  NGG        non-targeting
# 406      chrC            0          0      +  NGG        non-targeting
# 407      chrC            0          0      +  NGG        non-targeting
# 408      chrC            0          0      +  NGG        non-targeting
# 409      chrC            0          0      +  NGG        non-targeting
# 410      chrC            0          0      +  NGG        non-targeting
# 411      chrC            0          0      +  NGG        non-targeting
# 412      chrC            0          0      +  NGG        non-targeting
# 413      chrC            0          0      +  NGG        non-targeting
# 414      chrC            0          0      +  NGG        non-targeting
#
#     intended_target_chr  intended_target_start  intended_target_end  \
# 385               chrPC                      0                    0
# 386               chrPC                      0                    0
# 387               chrPC                      0                    0
# 388               chrPC                      0                    0
# 389               chrPC                      0                    0
# 390               chrPC                      0                    0
# 391               chrPC                      0                    0
# 392               chrPC                      0                    0
# 393               chrPC                      0                    0
# 394               chrPC                      0                    0
# 395               chrPC                      0                    0
# 396               chrPC                      0                    0
# 397               chrPC                      0                    0
# 398               chrPC                      0                    0
# 399               chrPC                      0                    0
# 400               chrPC                      0                    0
# 401               chrPC                      0                    0
# 402               chrPC                      0                    0
# 403               chrPC                      0                    0
# 404               chrPC                      0                    0
# 405               chrPC                      0                    0
# 406               chrPC                      0                    0
# 407               chrPC                      0                    0
# 408               chrPC                      0                    0
# 409               chrPC                      0                    0
# 410               chrPC                      0                    0
# 411               chrPC                      0                    0
# 412               chrPC                      0                    0
# 413               chrPC                      0                    0
# 414               chrPC                      0                    0
#
#               Photospacer gene_id_gtf gene_name_gtf  overlap_length  \
# 385  GGAGTTAAGGCCTCGTCTAG         NaN           NaN             NaN
# 386  GTCCCAGGCTCTCCACTATG         NaN           NaN             NaN
# 387  GGACGCGTCTGCAAGAACGT         NaN           NaN             NaN
# 388  GGGCATGGACCCGCGGCACG         NaN           NaN             NaN
# 389  GCGTCCGAGGTACTGAATAA         NaN           NaN             NaN
# 390  GTCTGACTCTCCGTCCACCA         NaN           NaN             NaN
# 391  GAGCCCCGCCTGGGTACGCG         NaN           NaN             NaN
# 392  GGGCACCGCCGTTAAAAGTT         NaN           NaN             NaN
# 393  GCTACAACCGGCGAGCGATA         NaN           NaN             NaN
# 394  GTAACTGCTACGGCGCCCAA         NaN           NaN             NaN
# 395  GGGATCAGTGAGGTCGGCCT         NaN           NaN             NaN
# 396  GGGTTCGAGCCAGAGACCGG         NaN           NaN             NaN
# 397  GCTATCCTAGACGAAAATCG         NaN           NaN             NaN
# 398  GCTACCCGGGTAGTGGCGAG         NaN           NaN             NaN
# 399  GGGTGGCCTGAGCTAGTACA         NaN           NaN             NaN
# 400  GGAGCTAGGATCGAACGACA         NaN           NaN             NaN
# 401  GCTTACGAGGGGGCGCTGCT         NaN           NaN             NaN
# 402  GGGGTGTCGGCAACACCGCG         NaN           NaN             NaN
# 403  GTGTACGGCCGTATGGAGCT         NaN           NaN             NaN
# 404  GGGCCCTTGAGGCGGGCCGA         NaN           NaN             NaN
# 405  GCTAACAAATACATCGGCAG         NaN           NaN             NaN
# 406  GTATATACGGCGGTCGTATC         NaN           NaN             NaN
# 407  GGGGCGCCCGGAGACTATCC         NaN           NaN             NaN
# 408  GATTGCGCAAGCCAGGTTAC         NaN           NaN             NaN
# 409  GGTACGCCTGCGGTCGAGTA         NaN           NaN             NaN
# 410  GGGCCCGCCACGCCGTAACC         NaN           NaN             NaN
# 411  GGAAAACTGTGCCCCCCTTA         NaN           NaN             NaN
# 412  GACCGGCATCAGCCGAGGGG         NaN           NaN             NaN
# 413  GCCCCGGCGGACAAAACCGG         NaN           NaN             NaN
# 414  GAGAGGTCGGATACGCTTCC         NaN           NaN             NaN
#
#     gene_name_mygene      gene_name
# 385              NaN  non-targeting
# 386              NaN  non-targeting
# 387              NaN  non-targeting
# 388              NaN  non-targeting
# 389              NaN  non-targeting
# 390              NaN  non-targeting
# 391              NaN  non-targeting
# 392              NaN  non-targeting
# 393              NaN  non-targeting
# 394              NaN  non-targeting
# 395              NaN  non-targeting
# 396              NaN  non-targeting
# 397              NaN  non-targeting
# 398              NaN  non-targeting
# 399              NaN  non-targeting
# 400              NaN  non-targeting
# 401              NaN  non-targeting
# 402              NaN  non-targeting
# 403              NaN  non-targeting
# 404              NaN  non-targeting
# 405              NaN  non-targeting
# 406              NaN  non-targeting
# 407              NaN  non-targeting
# 408              NaN  non-targeting
# 409              NaN  non-targeting
# 410              NaN  non-targeting
# 411              NaN  non-targeting
# 412              NaN  non-targeting
# 413              NaN  non-targeting
# 414              NaN  non-targeting

# %%
# check if non-targeting in ref
nt_metadata["in_ref"] = nt_metadata["Photospacer"].isin(ref_nt["Photospacer"])
nt_metadata["in_ref"].value_counts()
# Out:
# /tmp/ipykernel_1267871/2622200913.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nt_metadata["in_ref"] = nt_metadata["Photospacer"].isin(ref_nt["Photospacer"])
# in_ref
# True    30
# Name: count, dtype: int64

# %%
# 
len(nt_metadata)
# Out:
# 30

# %%
# set guide_chr	guide_start	guide_end	strand	PAM to NaN
nt_metadata["guide_chr"] = np.nan
nt_metadata["guide_start"] = np.nan
nt_metadata["guide_end"] = np.nan
nt_metadata["strand"] = np.nan
nt_metadata["PAM"] = np.nan
nt_metadata["intended_target_name"] = np.nan
nt_metadata["intended_target_chr"] = np.nan
nt_metadata["intended_target_start"] = np.nan
nt_metadata["intended_target_end"] = np.nan
nt_metadata["gene"] = np.nan
nt_metadata["label"] = "non_targeting"
# Out:
# /tmp/ipykernel_1267871/1125776720.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nt_metadata["guide_chr"] = np.nan
# /tmp/ipykernel_1267871/1125776720.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nt_metadata["guide_start"] = np.nan
# /tmp/ipykernel_1267871/1125776720.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nt_metadata["guide_end"] = np.nan
# /tmp/ipykernel_1267871/1125776720.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nt_metadata["strand"] = np.nan
# /tmp/ipykernel_1267871/1125776720.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nt_metadata["PAM"] = np.nan
# /tmp/ipykernel_1267871/1125776720.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nt_metadata["intended_target_name"] = np.nan
# /tmp/ipykernel_1267871/1125776720.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nt_metadata["intended_target_chr"] = np.nan
# /tmp/ipykernel_1267871/1125776720.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nt_metadata["intended_target_start"] = np.nan
# /tmp/ipykernel_1267871/1125776720.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nt_metadata["intended_target_end"] = np.nan
# /tmp/ipykernel_1267871/1125776720.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nt_metadata["gene"] = np.nan
# /tmp/ipykernel_1267871/1125776720.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nt_metadata["label"] = "non_targeting"

# %%
nt_clean_metadata = nt_metadata[["guide_id", "spacer", "targeting", "type", "guide_start", "guide_end", "guide_chr", "strand", "PAM",
             "intended_target_name", "intended_target_chr", "intended_target_start", "intended_target_end",
             "gene_name", "label"]]
nt_clean_metadata.head()
# Out:
#                 guide_id               spacer  targeting           type  \
# 385  non-targeting_00642  GAGTTAAGGCCTCGTCTAG      False  non-targeting
# 386  non-targeting_00718  TCCCAGGCTCTCCACTATG      False  non-targeting
# 387  non-targeting_03631  GACGCGTCTGCAAGAACGT      False  non-targeting
# 388  non-targeting_03705  GGCATGGACCCGCGGCACG      False  non-targeting
# 389  non-targeting_01469  CGTCCGAGGTACTGAATAA      False  non-targeting
#
#      guide_start  guide_end  guide_chr  strand  PAM  intended_target_name  \
# 385          NaN        NaN        NaN     NaN  NaN                   NaN
# 386          NaN        NaN        NaN     NaN  NaN                   NaN
# 387          NaN        NaN        NaN     NaN  NaN                   NaN
# 388          NaN        NaN        NaN     NaN  NaN                   NaN
# 389          NaN        NaN        NaN     NaN  NaN                   NaN
#
#      intended_target_chr  intended_target_start  intended_target_end  \
# 385                  NaN                    NaN                  NaN
# 386                  NaN                    NaN                  NaN
# 387                  NaN                    NaN                  NaN
# 388                  NaN                    NaN                  NaN
# 389                  NaN                    NaN                  NaN
#
#          gene_name          label
# 385  non-targeting  non_targeting
# 386  non-targeting  non_targeting
# 387  non-targeting  non_targeting
# 388  non-targeting  non_targeting
# 389  non-targeting  non_targeting

# %% [markdown]
# # Inspect targeting metadata

# %%
# Grab only the guides targeting targetings
targeting_metadata = guide_metadata[guide_metadata["targeting"] == True]

# Check Photospacer column against all spacers in ref_targeting_long
targeting_metadata["in_tf_ref"] = targeting_metadata["Photospacer"].isin(ref_tf_long["Photospacer"])
targeting_metadata["in_nc_ref"] = targeting_metadata["Photospacer"].isin(ref_nc_all["Photospacer"])

# OR genes
targeting_metadata["is_OR_gene"] = (targeting_metadata["gene_name_mygene"].replace(np.nan, "NA").str.startswith("OR")) | (targeting_metadata["gene_name_gtf"].replace(np.nan, "NA").str.startswith("OR")) 

# Check
targeting_metadata[targeting_metadata.columns[:8]]
# Out:
# /tmp/ipykernel_1267871/262495988.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targeting_metadata["in_tf_ref"] = targeting_metadata["Photospacer"].isin(ref_tf_long["Photospacer"])
# /tmp/ipykernel_1267871/262495988.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targeting_metadata["in_nc_ref"] = targeting_metadata["Photospacer"].isin(ref_nc_all["Photospacer"])
# /tmp/ipykernel_1267871/262495988.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targeting_metadata["is_OR_gene"] = (targeting_metadata["gene_name_mygene"].replace(np.nan, "NA").str.startswith("OR")) | (targeting_metadata["gene_name_gtf"].replace(np.nan, "NA").str.startswith("OR"))
#                         guide_id               spacer  targeting       type  \
# 0    chr5:132963540-132963558(+)  GGGCGGGTTAACGAAGACC       True  targeting
# 1    chr5:132963579-132963597(-)  TCGCCGCCGCCAGCGGACG       True  targeting
# 2    chr5:132963567-132963585(+)  GGATCCCCGCCCCGTCCGC       True  targeting
# 3    chr5:132963620-132963638(+)  AGGGCTGTGACTGACGCAG       True  targeting
# 4    chr5:132963570-132963588(+)  TCCCCGCCCCGTCCGCTGG       True  targeting
# ..                           ...                  ...        ...        ...
# 373  chr2:121284700-121284718(+)  CGATACGCGGGGGAGAGGA       True  targeting
# 374  chr2:121285141-121285159(+)  CGGCAGCAAGCGCAGACGC       True  targeting
# 375  chr2:121284796-121284814(+)  AGGAGCCCTCGCAGACATA       True  targeting
# 376  chr2:121285161-121285179(+)  GGGCGCGCCGAGGACCCAG       True  targeting
# 377  chr2:121284793-121284811(-)  GTCTGCGAGGGCTCCTCCC       True  targeting
#
#     guide_chr  guide_start  guide_end strand
# 0        chr5    132963540  132963540      +
# 1        chr5    132963579  132963579      -
# 2        chr5    132963567  132963567      +
# 3        chr5    132963620  132963620      +
# 4        chr5    132963570  132963570      +
# ..        ...          ...        ...    ...
# 373      chr2    121284700  121284700      +
# 374      chr2    121285141  121285141      +
# 375      chr2    121284796  121284796      +
# 376      chr2    121285161  121285161      +
# 377      chr2    121284793  121284793      -
#
# [378 rows x 8 columns]

# %%
# How many
targeting_metadata["in_nc_ref"].sum(), targeting_metadata["in_tf_ref"].sum()
# Out:
# (29, 288)

# %%
pd.crosstab(targeting_metadata["in_nc_ref"], targeting_metadata["is_OR_gene"])
# Out:
# is_OR_gene  False  True
# in_nc_ref
# False         324     25
# True            0     29

# %%
# Clean
targeting_metadata["new_guide_id"] = targeting_metadata["gene_name"] + "#" + targeting_metadata["guide_id"]
targeting_metadata["guide_end"] = targeting_metadata["guide_id"].str.split("-").str[1].str.split("(").str[0]
# Out:
# /tmp/ipykernel_1267871/1107272991.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targeting_metadata["new_guide_id"] = targeting_metadata["gene_name"] + "#" + targeting_metadata["guide_id"]
# /tmp/ipykernel_1267871/1107272991.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targeting_metadata["guide_end"] = targeting_metadata["guide_id"].str.split("-").str[1].str.split("(").str[0]

# %% [markdown]
# ## Negative control targets

# %%
nc_metadata = targeting_metadata[targeting_metadata["is_OR_gene"] == True]
len(nc_metadata)
# Out:
# 54

# %%
nc_metadata["in_tf_ref"].sum(), nc_metadata["in_nc_ref"].sum()
# Out:
# (0, 29)

# %%
nc_metadata[nc_metadata["in_nc_ref"]]["gene_name"].value_counts()
# Out:
# gene_name
# OR10J3    6
# OR2A25    6
# OR2AG2    6
# OR6A2     6
# OR2D3     1
# OR2F1     1
# OR4D6     1
# OR4X1     1
# OR6T1     1
# Name: count, dtype: int64

# %%
nc_metadata[nc_metadata["in_nc_ref"]]
# Out:
#                          guide_id               spacer  targeting       type  \
# 156   chr1:159314543-159314561(+)  AGTCAGCAGGTACAAAGTT       True  targeting
# 157   chr1:159314622-159314640(+)  AGGAACTCAGTCACAAAAG       True  targeting
# 158   chr1:159314586-159314604(+)  TTGTGCTGCCGCCTGAAGC       True  targeting
# 159   chr1:159314450-159314468(+)  AGAGATGGATAGCATGCAC       True  targeting
# 160   chr1:159314635-159314653(+)  CAAAAGTGGAATTTAGCTT       True  targeting
# 161   chr1:159314202-159314220(+)  CCAATCCCCAGTGATCCAG       True  targeting
# 162   chr7:144074196-144074214(+)  GCTCCTTGTTTCTTCTACA       True  targeting
# 163   chr7:144074203-144074221(+)  GTTTCTTCTACAGGGAAAT       True  targeting
# 164   chr7:144074434-144074452(-)  GGCACCGTGCTGCAAGCAC       True  targeting
# 165   chr7:144074335-144074353(+)  TGGGGAACGGGACAATCCT       True  targeting
# 166   chr7:144074604-144074622(-)  TGATGGTAGAATATCGGAG       True  targeting
# 167   chr7:144074317-144074335(+)  TCTACATCTTCATTCTGTT       True  targeting
# 168      chr11:6768936-6768954(-)  GAGCTCCGGAACTCCACCT       True  targeting
# 169      chr11:6768913-6768931(-)  AAGCGGCTTCATCTTGGTG       True  targeting
# 170      chr11:6768980-6768998(+)  GAACCAAATATATTATCAG       True  targeting
# 171      chr11:6768838-6768856(+)  GGTCAGTGCCAACATGTAT       True  targeting
# 172      chr11:6769013-6769031(+)  AAGGTGTTCACTCTAGCTT       True  targeting
# 173      chr11:6769024-6769042(+)  TCTAGCTTTGGATTGTTCT       True  targeting
# 176      chr11:6921033-6921051(+)  AACAGGCAAAAATATCAAT       True  targeting
# 180   chr7:143960021-143960039(-)  AGTGTCCCAGTCACTGGAC       True  targeting
# 190    chr11:59457005-59457023(-)  TCGGGAACGTGTAAGTTCC       True  targeting
# 196    chr11:48264242-48264260(-)  TGATGGCCATGTAGTGCAA       True  targeting
# 198      chr11:6795743-6795761(+)  AGAGTAGAGAGTCTTCAGT       True  targeting
# 199      chr11:6795708-6795726(-)  GTAAGAGAGACCAATGACA       True  targeting
# 200      chr11:6795803-6795821(+)  ATTGGTCGAATACCACGTA       True  targeting
# 201      chr11:6795776-6795794(+)  ACCCAGCCTTTCTCTTAAT       True  targeting
# 202      chr11:6795869-6795887(+)  TTAATCTGGAAATGAGCTA       True  targeting
# 203      chr11:6795688-6795706(-)  GGAGTGGCGGAACCATAGT       True  targeting
# 208  chr11:123943755-123943773(+)  GAACACCAGGAACTGTATG       True  targeting
#
#     guide_chr  guide_start  guide_end strand  PAM intended_target_name  ...  \
# 156      chr1    159314543  159314561      +  NGG      ENSG00000291901  ...
# 157      chr1    159314622  159314640      +  NGG      ENSG00000291901  ...
# 158      chr1    159314586  159314604      +  NGG      ENSG00000291901  ...
# 159      chr1    159314450  159314468      +  NGG      ENSG00000291901  ...
# 160      chr1    159314635  159314653      +  NGG      ENSG00000291901  ...
# 161      chr1    159314202  159314220      +  NGG      ENSG00000291901  ...
# 162      chr7    144074196  144074214      +  NGG    ENSG00000221933.3  ...
# 163      chr7    144074203  144074221      +  NGG    ENSG00000221933.3  ...
# 164      chr7    144074434  144074452      -  NGG    ENSG00000221933.3  ...
# 165      chr7    144074335  144074353      +  NGG    ENSG00000221933.3  ...
# 166      chr7    144074604  144074622      -  NGG    ENSG00000221933.3  ...
# 167      chr7    144074317  144074335      +  NGG    ENSG00000221933.3  ...
# 168     chr11      6768936    6768954      -  NGG      ENSG00000188124  ...
# 169     chr11      6768913    6768931      -  NGG      ENSG00000188124  ...
# 170     chr11      6768980    6768998      +  NGG      ENSG00000188124  ...
# 171     chr11      6768838    6768856      +  NGG      ENSG00000188124  ...
# 172     chr11      6769013    6769031      +  NGG      ENSG00000188124  ...
# 173     chr11      6769024    6769042      +  NGG      ENSG00000188124  ...
# 176     chr11      6921033    6921051      +  NGG      ENSG00000178358  ...
# 180      chr7    143960021  143960039      -  NGG    ENSG00000213215.5  ...
# 190     chr11     59457005   59457023      -  NGG      ENSG00000166884  ...
# 196     chr11     48264242   48264260      -  NGG      ENSG00000176567  ...
# 198     chr11      6795743    6795761      +  NGG      ENSG00000184933  ...
# 199     chr11      6795708    6795726      -  NGG      ENSG00000184933  ...
# 200     chr11      6795803    6795821      +  NGG      ENSG00000184933  ...
# 201     chr11      6795776    6795794      +  NGG      ENSG00000184933  ...
# 202     chr11      6795869    6795887      +  NGG      ENSG00000184933  ...
# 203     chr11      6795688    6795706      -  NGG      ENSG00000184933  ...
# 208     chr11    123943755  123943773      +  NGG      ENSG00000181499  ...
#
#               Photospacer        gene_id_gtf  gene_name_gtf overlap_length  \
# 156  GAGTCAGCAGGTACAAAGTT  ENSG00000196266.6         OR10J3          451.0
# 157  GAGGAACTCAGTCACAAAAG  ENSG00000196266.6         OR10J3          451.0
# 158  GTTGTGCTGCCGCCTGAAGC  ENSG00000196266.6         OR10J3          451.0
# 159  GAGAGATGGATAGCATGCAC  ENSG00000196266.6         OR10J3          451.0
# 160  GCAAAAGTGGAATTTAGCTT  ENSG00000196266.6         OR10J3          451.0
# 161  GCCAATCCCCAGTGATCCAG  ENSG00000196266.6         OR10J3          451.0
# 162  GGCTCCTTGTTTCTTCTACA  ENSG00000221933.3         OR2A25          426.0
# 163  GGTTTCTTCTACAGGGAAAT  ENSG00000221933.3         OR2A25          426.0
# 164  GGGCACCGTGCTGCAAGCAC  ENSG00000221933.3         OR2A25          426.0
# 165  GTGGGGAACGGGACAATCCT  ENSG00000221933.3         OR2A25          426.0
# 166  GTGATGGTAGAATATCGGAG  ENSG00000221933.3         OR2A25          426.0
# 167  GTCTACATCTTCATTCTGTT  ENSG00000221933.3         OR2A25          426.0
# 168  GGAGCTCCGGAACTCCACCT  ENSG00000188124.4         OR2AG2          204.0
# 169  GAAGCGGCTTCATCTTGGTG  ENSG00000188124.4         OR2AG2          204.0
# 170  GGAACCAAATATATTATCAG  ENSG00000188124.4         OR2AG2          204.0
# 171  GGGTCAGTGCCAACATGTAT  ENSG00000188124.4         OR2AG2          204.0
# 172  GAAGGTGTTCACTCTAGCTT  ENSG00000188124.4         OR2AG2          204.0
# 173  GTCTAGCTTTGGATTGTTCT  ENSG00000188124.4         OR2AG2          204.0
# 176  GAACAGGCAAAAATATCAAT  ENSG00000178358.5          OR2D3          203.0
# 180  GAGTGTCCCAGTCACTGGAC  ENSG00000213215.5          OR2F1          436.0
# 190  GTCGGGAACGTGTAAGTTCC  ENSG00000166884.3          OR4D6           63.0
# 196  GTGATGGCCATGTAGTGCAA  ENSG00000176567.1          OR4X1          424.0
# 198  GAGAGTAGAGAGTCTTCAGT  ENSG00000184933.6          OR6A2          199.0
# 199  GGTAAGAGAGACCAATGACA  ENSG00000184933.6          OR6A2          199.0
# 200  GATTGGTCGAATACCACGTA  ENSG00000184933.6          OR6A2          199.0
# 201  GACCCAGCCTTTCTCTTAAT  ENSG00000184933.6          OR6A2          199.0
# 202  GTTAATCTGGAAATGAGCTA  ENSG00000184933.6          OR6A2          199.0
# 203  GGGAGTGGCGGAACCATAGT  ENSG00000184933.6          OR6A2          199.0
# 208  GGAACACCAGGAACTGTATG  ENSG00000181499.3          OR6T1          442.0
#
#     gene_name_mygene gene_name  in_tf_ref in_nc_ref is_OR_gene  \
# 156           OR10J3    OR10J3      False      True       True
# 157           OR10J3    OR10J3      False      True       True
# 158           OR10J3    OR10J3      False      True       True
# 159           OR10J3    OR10J3      False      True       True
# 160           OR10J3    OR10J3      False      True       True
# 161           OR10J3    OR10J3      False      True       True
# 162              NaN    OR2A25      False      True       True
# 163              NaN    OR2A25      False      True       True
# 164              NaN    OR2A25      False      True       True
# 165              NaN    OR2A25      False      True       True
# 166              NaN    OR2A25      False      True       True
# 167              NaN    OR2A25      False      True       True
# 168           OR2AG2    OR2AG2      False      True       True
# 169           OR2AG2    OR2AG2      False      True       True
# 170           OR2AG2    OR2AG2      False      True       True
# 171           OR2AG2    OR2AG2      False      True       True
# 172           OR2AG2    OR2AG2      False      True       True
# 173           OR2AG2    OR2AG2      False      True       True
# 176            OR2D3     OR2D3      False      True       True
# 180              NaN     OR2F1      False      True       True
# 190            OR4D6     OR4D6      False      True       True
# 196            OR4X1     OR4X1      False      True       True
# 198            OR6A2     OR6A2      False      True       True
# 199            OR6A2     OR6A2      False      True       True
# 200            OR6A2     OR6A2      False      True       True
# 201            OR6A2     OR6A2      False      True       True
# 202            OR6A2     OR6A2      False      True       True
# 203            OR6A2     OR6A2      False      True       True
# 208            OR6T1     OR6T1      False      True       True
#
#                            new_guide_id
# 156  OR10J3#chr1:159314543-159314561(+)
# 157  OR10J3#chr1:159314622-159314640(+)
# 158  OR10J3#chr1:159314586-159314604(+)
# 159  OR10J3#chr1:159314450-159314468(+)
# 160  OR10J3#chr1:159314635-159314653(+)
# 161  OR10J3#chr1:159314202-159314220(+)
# 162  OR2A25#chr7:144074196-144074214(+)
# 163  OR2A25#chr7:144074203-144074221(+)
# 164  OR2A25#chr7:144074434-144074452(-)
# 165  OR2A25#chr7:144074335-144074353(+)
# 166  OR2A25#chr7:144074604-144074622(-)
# 167  OR2A25#chr7:144074317-144074335(+)
# 168     OR2AG2#chr11:6768936-6768954(-)
# 169     OR2AG2#chr11:6768913-6768931(-)
# 170     OR2AG2#chr11:6768980-6768998(+)
# 171     OR2AG2#chr11:6768838-6768856(+)
# 172     OR2AG2#chr11:6769013-6769031(+)
# 173     OR2AG2#chr11:6769024-6769042(+)
# 176      OR2D3#chr11:6921033-6921051(+)
# 180   OR2F1#chr7:143960021-143960039(-)
# 190    OR4D6#chr11:59457005-59457023(-)
# 196    OR4X1#chr11:48264242-48264260(-)
# 198      OR6A2#chr11:6795743-6795761(+)
# 199      OR6A2#chr11:6795708-6795726(-)
# 200      OR6A2#chr11:6795803-6795821(+)
# 201      OR6A2#chr11:6795776-6795794(+)
# 202      OR6A2#chr11:6795869-6795887(+)
# 203      OR6A2#chr11:6795688-6795706(-)
# 208  OR6T1#chr11:123943755-123943773(+)
#
# [29 rows x 23 columns]

# %%
nc_metadata[~nc_metadata["in_nc_ref"]]["gene_name"].value_counts()
# Out:
# gene_name
# OR2D3    5
# OR2F1    5
# OR4D6    5
# OR4X1    5
# OR6T1    5
# Name: count, dtype: int64

# %%
nc_metadata["gene_name"].value_counts()
# Out:
# gene_name
# OR10J3    6
# OR2A25    6
# OR2AG2    6
# OR2D3     6
# OR2F1     6
# OR4D6     6
# OR4X1     6
# OR6A2     6
# OR6T1     6
# Name: count, dtype: int64

# %%
nc_metadata["gene_name"].unique()
# Out:
# array(['OR10J3', 'OR2A25', 'OR2AG2', 'OR2D3', 'OR2F1', 'OR4D6', 'OR4X1',
#        'OR6A2', 'OR6T1'], dtype=object)

# %%
nc_metadata["label"] = "negative_control"
# Out:
# /tmp/ipykernel_1267871/1424922385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nc_metadata["label"] = "negative_control"

# %%
nc_clean_metadata = nc_metadata[["new_guide_id", "spacer", "targeting", "type",
             "guide_chr", "guide_start", "guide_end", "strand", "PAM",
             "intended_target_name", "intended_target_chr", "intended_target_start", "intended_target_end",
             "gene_name", "label"]].rename(columns={"new_guide_id": "guide_id"})
nc_clean_metadata
# Out:
#                                guide_id               spacer  targeting  \
# 156  OR10J3#chr1:159314543-159314561(+)  AGTCAGCAGGTACAAAGTT       True
# 157  OR10J3#chr1:159314622-159314640(+)  AGGAACTCAGTCACAAAAG       True
# 158  OR10J3#chr1:159314586-159314604(+)  TTGTGCTGCCGCCTGAAGC       True
# 159  OR10J3#chr1:159314450-159314468(+)  AGAGATGGATAGCATGCAC       True
# 160  OR10J3#chr1:159314635-159314653(+)  CAAAAGTGGAATTTAGCTT       True
# 161  OR10J3#chr1:159314202-159314220(+)  CCAATCCCCAGTGATCCAG       True
# 162  OR2A25#chr7:144074196-144074214(+)  GCTCCTTGTTTCTTCTACA       True
# 163  OR2A25#chr7:144074203-144074221(+)  GTTTCTTCTACAGGGAAAT       True
# 164  OR2A25#chr7:144074434-144074452(-)  GGCACCGTGCTGCAAGCAC       True
# 165  OR2A25#chr7:144074335-144074353(+)  TGGGGAACGGGACAATCCT       True
# 166  OR2A25#chr7:144074604-144074622(-)  TGATGGTAGAATATCGGAG       True
# 167  OR2A25#chr7:144074317-144074335(+)  TCTACATCTTCATTCTGTT       True
# 168     OR2AG2#chr11:6768936-6768954(-)  GAGCTCCGGAACTCCACCT       True
# 169     OR2AG2#chr11:6768913-6768931(-)  AAGCGGCTTCATCTTGGTG       True
# 170     OR2AG2#chr11:6768980-6768998(+)  GAACCAAATATATTATCAG       True
# 171     OR2AG2#chr11:6768838-6768856(+)  GGTCAGTGCCAACATGTAT       True
# 172     OR2AG2#chr11:6769013-6769031(+)  AAGGTGTTCACTCTAGCTT       True
# 173     OR2AG2#chr11:6769024-6769042(+)  TCTAGCTTTGGATTGTTCT       True
# 174      OR2D3#chr11:6921025-6921043(-)  TTTTGCCTGTTTACCTGTT       True
# 175      OR2D3#chr11:6921094-6921112(-)  CAAGTCCTGTGAAAGACCC       True
# 176      OR2D3#chr11:6921033-6921051(+)  AACAGGCAAAAATATCAAT       True
# 177      OR2D3#chr11:6921017-6921035(+)  TTGTGCCAAACAGGTAAAC       True
# 178      OR2D3#chr11:6921067-6921085(-)  AAACTTGGACACAAAGGTT       True
# 179      OR2D3#chr11:6921202-6921220(-)  AGTGTGAAGGCGAGAATCC       True
# 180   OR2F1#chr7:143960021-143960039(-)  AGTGTCCCAGTCACTGGAC       True
# 181   OR2F1#chr7:143960194-143960212(-)  AGCTGAGGGACTACACTTG       True
# 182   OR2F1#chr7:143960013-143960031(+)  CTCGGCCTGTCCAGTGACT       True
# 183   OR2F1#chr7:143959941-143959959(-)  AGGATTATTAATCTGTGAA       True
# 184   OR2F1#chr7:143960051-143960069(-)  GACCAAGAACAGGACAAAC       True
# 185   OR2F1#chr7:143960359-143960377(-)  ATGATGGCCGAGTATCGCA       True
# 186    OR4D6#chr11:59456921-59456939(+)  CTTCATCAAAGGTAGGACC       True
# 187    OR4D6#chr11:59456969-59456987(-)  CACATTAGTGTGGTTGATC       True
# 188    OR4D6#chr11:59456958-59456976(-)  GGTTGATCTGGTCCATGAT       True
# 189    OR4D6#chr11:59456915-59456933(+)  ACATATCTTCATCAAAGGT       True
# 190    OR4D6#chr11:59457005-59457023(-)  TCGGGAACGTGTAAGTTCC       True
# 191    OR4D6#chr11:59456943-59456961(+)  AAGAGAGTCATCCCCATCA       True
# 192    OR4X1#chr11:48263880-48263898(+)  TGACTGAAATAATTTTCGT       True
# 193    OR4X1#chr11:48264090-48264108(-)  GAGTCAAAGATAAGCTTGG       True
# 194    OR4X1#chr11:48263953-48263971(-)  CACAACAGCTGTGTACATG       True
# 195    OR4X1#chr11:48264286-48264304(-)  GCCCCATGCTATCCTCACG       True
# 196    OR4X1#chr11:48264242-48264260(-)  TGATGGCCATGTAGTGCAA       True
# 197    OR4X1#chr11:48264281-48264299(+)  CTCCTCGTGAGGATAGCAT       True
# 198      OR6A2#chr11:6795743-6795761(+)  AGAGTAGAGAGTCTTCAGT       True
# 199      OR6A2#chr11:6795708-6795726(-)  GTAAGAGAGACCAATGACA       True
# 200      OR6A2#chr11:6795803-6795821(+)  ATTGGTCGAATACCACGTA       True
# 201      OR6A2#chr11:6795776-6795794(+)  ACCCAGCCTTTCTCTTAAT       True
# 202      OR6A2#chr11:6795869-6795887(+)  TTAATCTGGAAATGAGCTA       True
# 203      OR6A2#chr11:6795688-6795706(-)  GGAGTGGCGGAACCATAGT       True
# 204  OR6T1#chr11:123943516-123943534(+)  CCTAGAAAGAAGTAGAGGT       True
# 205  OR6T1#chr11:123943767-123943785(+)  CTGTATGAGGTGGCTACTG       True
# 206  OR6T1#chr11:123943618-123943636(+)  ACCAGCAACAGCTCCAGGA       True
# 207  OR6T1#chr11:123943393-123943411(+)  CAGGAGGCCAGCACTAGTT       True
# 208  OR6T1#chr11:123943755-123943773(+)  GAACACCAGGAACTGTATG       True
# 209  OR6T1#chr11:123943817-123943835(-)  AACCCTGAAAACTGGACTC       True
#
#           type guide_chr  guide_start  guide_end strand  PAM  \
# 156  targeting      chr1    159314543  159314561      +  NGG
# 157  targeting      chr1    159314622  159314640      +  NGG
# 158  targeting      chr1    159314586  159314604      +  NGG
# 159  targeting      chr1    159314450  159314468      +  NGG
# 160  targeting      chr1    159314635  159314653      +  NGG
# 161  targeting      chr1    159314202  159314220      +  NGG
# 162  targeting      chr7    144074196  144074214      +  NGG
# 163  targeting      chr7    144074203  144074221      +  NGG
# 164  targeting      chr7    144074434  144074452      -  NGG
# 165  targeting      chr7    144074335  144074353      +  NGG
# 166  targeting      chr7    144074604  144074622      -  NGG
# 167  targeting      chr7    144074317  144074335      +  NGG
# 168  targeting     chr11      6768936    6768954      -  NGG
# 169  targeting     chr11      6768913    6768931      -  NGG
# 170  targeting     chr11      6768980    6768998      +  NGG
# 171  targeting     chr11      6768838    6768856      +  NGG
# 172  targeting     chr11      6769013    6769031      +  NGG
# 173  targeting     chr11      6769024    6769042      +  NGG
# 174  targeting     chr11      6921025    6921043      -  NGG
# 175  targeting     chr11      6921094    6921112      -  NGG
# 176  targeting     chr11      6921033    6921051      +  NGG
# 177  targeting     chr11      6921017    6921035      +  NGG
# 178  targeting     chr11      6921067    6921085      -  NGG
# 179  targeting     chr11      6921202    6921220      -  NGG
# 180  targeting      chr7    143960021  143960039      -  NGG
# 181  targeting      chr7    143960194  143960212      -  NGG
# 182  targeting      chr7    143960013  143960031      +  NGG
# 183  targeting      chr7    143959941  143959959      -  NGG
# 184  targeting      chr7    143960051  143960069      -  NGG
# 185  targeting      chr7    143960359  143960377      -  NGG
# 186  targeting     chr11     59456921   59456939      +  NGG
# 187  targeting     chr11     59456969   59456987      -  NGG
# 188  targeting     chr11     59456958   59456976      -  NGG
# 189  targeting     chr11     59456915   59456933      +  NGG
# 190  targeting     chr11     59457005   59457023      -  NGG
# 191  targeting     chr11     59456943   59456961      +  NGG
# 192  targeting     chr11     48263880   48263898      +  NGG
# 193  targeting     chr11     48264090   48264108      -  NGG
# 194  targeting     chr11     48263953   48263971      -  NGG
# 195  targeting     chr11     48264286   48264304      -  NGG
# 196  targeting     chr11     48264242   48264260      -  NGG
# 197  targeting     chr11     48264281   48264299      +  NGG
# 198  targeting     chr11      6795743    6795761      +  NGG
# 199  targeting     chr11      6795708    6795726      -  NGG
# 200  targeting     chr11      6795803    6795821      +  NGG
# 201  targeting     chr11      6795776    6795794      +  NGG
# 202  targeting     chr11      6795869    6795887      +  NGG
# 203  targeting     chr11      6795688    6795706      -  NGG
# 204  targeting     chr11    123943516  123943534      +  NGG
# 205  targeting     chr11    123943767  123943785      +  NGG
# 206  targeting     chr11    123943618  123943636      +  NGG
# 207  targeting     chr11    123943393  123943411      +  NGG
# 208  targeting     chr11    123943755  123943773      +  NGG
# 209  targeting     chr11    123943817  123943835      -  NGG
#
#     intended_target_name intended_target_chr  intended_target_start  \
# 156      ENSG00000291901                chr1              159314202
# 157      ENSG00000291901                chr1              159314202
# 158      ENSG00000291901                chr1              159314202
# 159      ENSG00000291901                chr1              159314202
# 160      ENSG00000291901                chr1              159314202
# 161      ENSG00000291901                chr1              159314202
# 162    ENSG00000221933.3                chr7              144074196
# 163    ENSG00000221933.3                chr7              144074196
# 164    ENSG00000221933.3                chr7              144074196
# 165    ENSG00000221933.3                chr7              144074196
# 166    ENSG00000221933.3                chr7              144074196
# 167    ENSG00000221933.3                chr7              144074196
# 168      ENSG00000188124               chr11                6768838
# 169      ENSG00000188124               chr11                6768838
# 170      ENSG00000188124               chr11                6768838
# 171      ENSG00000188124               chr11                6768838
# 172      ENSG00000188124               chr11                6768838
# 173      ENSG00000188124               chr11                6768838
# 174      ENSG00000178358               chr11                6921017
# 175      ENSG00000178358               chr11                6921017
# 176      ENSG00000178358               chr11                6921017
# 177      ENSG00000178358               chr11                6921017
# 178      ENSG00000178358               chr11                6921017
# 179      ENSG00000178358               chr11                6921017
# 180    ENSG00000213215.5                chr7              143959941
# 181    ENSG00000213215.5                chr7              143959941
# 182    ENSG00000213215.5                chr7              143959941
# 183    ENSG00000213215.5                chr7              143959941
# 184    ENSG00000213215.5                chr7              143959941
# 185    ENSG00000213215.5                chr7              143959941
# 186      ENSG00000166884               chr11               59456915
# 187      ENSG00000166884               chr11               59456915
# 188      ENSG00000166884               chr11               59456915
# 189      ENSG00000166884               chr11               59456915
# 190      ENSG00000166884               chr11               59456915
# 191      ENSG00000166884               chr11               59456915
# 192      ENSG00000176567               chr11               48263880
# 193      ENSG00000176567               chr11               48263880
# 194      ENSG00000176567               chr11               48263880
# 195      ENSG00000176567               chr11               48263880
# 196      ENSG00000176567               chr11               48263880
# 197      ENSG00000176567               chr11               48263880
# 198      ENSG00000184933               chr11                6795688
# 199      ENSG00000184933               chr11                6795688
# 200      ENSG00000184933               chr11                6795688
# 201      ENSG00000184933               chr11                6795688
# 202      ENSG00000184933               chr11                6795688
# 203      ENSG00000184933               chr11                6795688
# 204      ENSG00000181499               chr11              123943393
# 205      ENSG00000181499               chr11              123943393
# 206      ENSG00000181499               chr11              123943393
# 207      ENSG00000181499               chr11              123943393
# 208      ENSG00000181499               chr11              123943393
# 209      ENSG00000181499               chr11              123943393
#
#      intended_target_end gene_name             label
# 156            159314653    OR10J3  negative_control
# 157            159314653    OR10J3  negative_control
# 158            159314653    OR10J3  negative_control
# 159            159314653    OR10J3  negative_control
# 160            159314653    OR10J3  negative_control
# 161            159314653    OR10J3  negative_control
# 162            144074622    OR2A25  negative_control
# 163            144074622    OR2A25  negative_control
# 164            144074622    OR2A25  negative_control
# 165            144074622    OR2A25  negative_control
# 166            144074622    OR2A25  negative_control
# 167            144074622    OR2A25  negative_control
# 168              6769042    OR2AG2  negative_control
# 169              6769042    OR2AG2  negative_control
# 170              6769042    OR2AG2  negative_control
# 171              6769042    OR2AG2  negative_control
# 172              6769042    OR2AG2  negative_control
# 173              6769042    OR2AG2  negative_control
# 174              6921220     OR2D3  negative_control
# 175              6921220     OR2D3  negative_control
# 176              6921220     OR2D3  negative_control
# 177              6921220     OR2D3  negative_control
# 178              6921220     OR2D3  negative_control
# 179              6921220     OR2D3  negative_control
# 180            143960377     OR2F1  negative_control
# 181            143960377     OR2F1  negative_control
# 182            143960377     OR2F1  negative_control
# 183            143960377     OR2F1  negative_control
# 184            143960377     OR2F1  negative_control
# 185            143960377     OR2F1  negative_control
# 186             59457023     OR4D6  negative_control
# 187             59457023     OR4D6  negative_control
# 188             59457023     OR4D6  negative_control
# 189             59457023     OR4D6  negative_control
# 190             59457023     OR4D6  negative_control
# 191             59457023     OR4D6  negative_control
# 192             48264304     OR4X1  negative_control
# 193             48264304     OR4X1  negative_control
# 194             48264304     OR4X1  negative_control
# 195             48264304     OR4X1  negative_control
# 196             48264304     OR4X1  negative_control
# 197             48264304     OR4X1  negative_control
# 198              6795887     OR6A2  negative_control
# 199              6795887     OR6A2  negative_control
# 200              6795887     OR6A2  negative_control
# 201              6795887     OR6A2  negative_control
# 202              6795887     OR6A2  negative_control
# 203              6795887     OR6A2  negative_control
# 204            123943835     OR6T1  negative_control
# 205            123943835     OR6T1  negative_control
# 206            123943835     OR6T1  negative_control
# 207            123943835     OR6T1  negative_control
# 208            123943835     OR6T1  negative_control
# 209            123943835     OR6T1  negative_control

# %% [markdown]
# ## TF targets

# %%
tf_metadata = targeting_metadata[targeting_metadata["is_OR_gene"] == False]
tf_metadata
# Out:
#                         guide_id               spacer  targeting       type  \
# 0    chr5:132963540-132963558(+)  GGGCGGGTTAACGAAGACC       True  targeting
# 1    chr5:132963579-132963597(-)  TCGCCGCCGCCAGCGGACG       True  targeting
# 2    chr5:132963567-132963585(+)  GGATCCCCGCCCCGTCCGC       True  targeting
# 3    chr5:132963620-132963638(+)  AGGGCTGTGACTGACGCAG       True  targeting
# 4    chr5:132963570-132963588(+)  TCCCCGCCCCGTCCGCTGG       True  targeting
# ..                           ...                  ...        ...        ...
# 373  chr2:121284700-121284718(+)  CGATACGCGGGGGAGAGGA       True  targeting
# 374  chr2:121285141-121285159(+)  CGGCAGCAAGCGCAGACGC       True  targeting
# 375  chr2:121284796-121284814(+)  AGGAGCCCTCGCAGACATA       True  targeting
# 376  chr2:121285161-121285179(+)  GGGCGCGCCGAGGACCCAG       True  targeting
# 377  chr2:121284793-121284811(-)  GTCTGCGAGGGCTCCTCCC       True  targeting
#
#     guide_chr  guide_start  guide_end strand  PAM intended_target_name  ...  \
# 0        chr5    132963540  132963558      +  NGG      ENSG00000072364  ...
# 1        chr5    132963579  132963597      -  NGG      ENSG00000072364  ...
# 2        chr5    132963567  132963585      +  NGG      ENSG00000072364  ...
# 3        chr5    132963620  132963638      +  NGG      ENSG00000072364  ...
# 4        chr5    132963570  132963588      +  NGG      ENSG00000072364  ...
# ..        ...          ...        ...    ...  ...                  ...  ...
# 373      chr2    121284700  121284718      +  NGG      ENSG00000115112  ...
# 374      chr2    121285141  121285159      +  NGG      ENSG00000115112  ...
# 375      chr2    121284796  121284814      +  NGG      ENSG00000115112  ...
# 376      chr2    121285161  121285179      +  NGG      ENSG00000115112  ...
# 377      chr2    121284793  121284811      -  NGG      ENSG00000115112  ...
#
#               Photospacer         gene_id_gtf  gene_name_gtf overlap_length  \
# 0    GGGGCGGGTTAACGAAGACC  ENSG00000072364.13           AFF4           94.0
# 1    GTCGCCGCCGCCAGCGGACG  ENSG00000072364.13           AFF4           94.0
# 2    GGGATCCCCGCCCCGTCCGC  ENSG00000072364.13           AFF4           94.0
# 3    GAGGGCTGTGACTGACGCAG  ENSG00000072364.13           AFF4           94.0
# 4    GTCCCCGCCCCGTCCGCTGG  ENSG00000072364.13           AFF4           94.0
# ..                    ...                 ...            ...            ...
# 373  GCGATACGCGGGGGAGAGGA   ENSG00000115112.8        TFCP2L1          479.0
# 374  GCGGCAGCAAGCGCAGACGC   ENSG00000115112.8        TFCP2L1          479.0
# 375  GAGGAGCCCTCGCAGACATA   ENSG00000115112.8        TFCP2L1          479.0
# 376  GGGGCGCGCCGAGGACCCAG   ENSG00000115112.8        TFCP2L1          479.0
# 377  GGTCTGCGAGGGCTCCTCCC   ENSG00000115112.8        TFCP2L1          479.0
#
#     gene_name_mygene gene_name  in_tf_ref in_nc_ref is_OR_gene  \
# 0               AFF4      AFF4       True     False      False
# 1               AFF4      AFF4       True     False      False
# 2               AFF4      AFF4       True     False      False
# 3               AFF4      AFF4       True     False      False
# 4               AFF4      AFF4       True     False      False
# ..               ...       ...        ...       ...        ...
# 373          TFCP2L1   TFCP2L1       True     False      False
# 374          TFCP2L1   TFCP2L1       True     False      False
# 375          TFCP2L1   TFCP2L1       True     False      False
# 376          TFCP2L1   TFCP2L1       True     False      False
# 377          TFCP2L1   TFCP2L1       True     False      False
#
#                             new_guide_id
# 0       AFF4#chr5:132963540-132963558(+)
# 1       AFF4#chr5:132963579-132963597(-)
# 2       AFF4#chr5:132963567-132963585(+)
# 3       AFF4#chr5:132963620-132963638(+)
# 4       AFF4#chr5:132963570-132963588(+)
# ..                                   ...
# 373  TFCP2L1#chr2:121284700-121284718(+)
# 374  TFCP2L1#chr2:121285141-121285159(+)
# 375  TFCP2L1#chr2:121284796-121284814(+)
# 376  TFCP2L1#chr2:121285161-121285179(+)
# 377  TFCP2L1#chr2:121284793-121284811(-)
#
# [324 rows x 23 columns]

# %%
tf_metadata["in_tf_ref"].sum(), tf_metadata["in_nc_ref"].sum()
# Out:
# (288, 0)

# %%
(~tf_metadata["in_tf_ref"]).sum()
# Out:
# 36

# %%
tf_metadata[(~tf_metadata["in_tf_ref"])]["gene_name"].value_counts()
# Out:
# gene_name
# SMARCD3    12
# EED         6
# JARID2      6
# SMARCD1     6
# SMARCD2     6
# Name: count, dtype: int64

# %%
tf_metadata["gene_name"].value_counts()
# Out:
# gene_name
# POU5F1     12
# SMARCB1    12
# ARID1B     12
# TCF12      12
# LEF1       12
# SMARCD3    12
# KLF4       12
# REST       12
# RUNX1       6
# SALL4       6
# SMAD3       6
# SMAD4       6
# SMARCA2     6
# SMARCA4     6
# AFF4        6
# SMARCC1     6
# SMARCC2     6
# SMARCD2     6
# SOX2        6
# SUZ12       6
# TBX3        6
# TCF7L1      6
# TCF7L2      6
# TCF7        6
# SMARCD1     6
# PAX5        6
# ARID1A      6
# NFIB        6
# BMAL1       6
# ARNT        6
# BATF        6
# CLOCK       6
# CREBBP      6
# CTNNB1      6
# EED         6
# EP300       6
# ESRRB       6
# EZH2        6
# HDAC1       6
# HIF1A       6
# HMGA2       6
# JARID2      6
# KLF6        6
# MYC         6
# NANOG       6
# TFCP2L1     6
# Name: count, dtype: int64

# %%
tf_metadata[tf_metadata["gene_name"] == "POU5F1"][["intended_target_start", "intended_target_end"]]
# Out:
#      intended_target_start  intended_target_end
# 216               31170169             31170720
# 217               31170169             31170720
# 218               31170169             31170720
# 219               31170169             31170720
# 220               31170169             31170720
# 221               31170169             31170720
# 222               31180431             31180710
# 223               31180431             31180710
# 224               31180431             31180710
# 225               31180431             31180710
# 226               31180431             31180710
# 227               31180431             31180710

# %%
len(tf_metadata["gene_name"].unique())
# Out:
# 46

# %%
tf_metadata["label"] = "tf_targeting"
# Out:
# /tmp/ipykernel_1267871/908768467.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tf_metadata["label"] = "tf_targeting"

# %%
tf_clean_metadata = tf_metadata[["new_guide_id", "spacer", "targeting", "type",
             "guide_chr", "guide_start", "guide_end", "strand", "PAM",
             "intended_target_name", "intended_target_chr", "intended_target_start", "intended_target_end",
             "gene_name", "label"]].rename(columns={"new_guide_id": "guide_id"})
tf_clean_metadata
# Out:
#                                 guide_id               spacer  targeting  \
# 0       AFF4#chr5:132963540-132963558(+)  GGGCGGGTTAACGAAGACC       True
# 1       AFF4#chr5:132963579-132963597(-)  TCGCCGCCGCCAGCGGACG       True
# 2       AFF4#chr5:132963567-132963585(+)  GGATCCCCGCCCCGTCCGC       True
# 3       AFF4#chr5:132963620-132963638(+)  AGGGCTGTGACTGACGCAG       True
# 4       AFF4#chr5:132963570-132963588(+)  TCCCCGCCCCGTCCGCTGG       True
# ..                                   ...                  ...        ...
# 373  TFCP2L1#chr2:121284700-121284718(+)  CGATACGCGGGGGAGAGGA       True
# 374  TFCP2L1#chr2:121285141-121285159(+)  CGGCAGCAAGCGCAGACGC       True
# 375  TFCP2L1#chr2:121284796-121284814(+)  AGGAGCCCTCGCAGACATA       True
# 376  TFCP2L1#chr2:121285161-121285179(+)  GGGCGCGCCGAGGACCCAG       True
# 377  TFCP2L1#chr2:121284793-121284811(-)  GTCTGCGAGGGCTCCTCCC       True
#
#           type guide_chr  guide_start  guide_end strand  PAM  \
# 0    targeting      chr5    132963540  132963558      +  NGG
# 1    targeting      chr5    132963579  132963597      -  NGG
# 2    targeting      chr5    132963567  132963585      +  NGG
# 3    targeting      chr5    132963620  132963638      +  NGG
# 4    targeting      chr5    132963570  132963588      +  NGG
# ..         ...       ...          ...        ...    ...  ...
# 373  targeting      chr2    121284700  121284718      +  NGG
# 374  targeting      chr2    121285141  121285159      +  NGG
# 375  targeting      chr2    121284796  121284814      +  NGG
# 376  targeting      chr2    121285161  121285179      +  NGG
# 377  targeting      chr2    121284793  121284811      -  NGG
#
#     intended_target_name intended_target_chr  intended_target_start  \
# 0        ENSG00000072364                chr5              132963540
# 1        ENSG00000072364                chr5              132963540
# 2        ENSG00000072364                chr5              132963540
# 3        ENSG00000072364                chr5              132963540
# 4        ENSG00000072364                chr5              132963540
# ..                   ...                 ...                    ...
# 373      ENSG00000115112                chr2              121284700
# 374      ENSG00000115112                chr2              121284700
# 375      ENSG00000115112                chr2              121284700
# 376      ENSG00000115112                chr2              121284700
# 377      ENSG00000115112                chr2              121284700
#
#      intended_target_end gene_name         label
# 0              132963638      AFF4  tf_targeting
# 1              132963638      AFF4  tf_targeting
# 2              132963638      AFF4  tf_targeting
# 3              132963638      AFF4  tf_targeting
# 4              132963638      AFF4  tf_targeting
# ..                   ...       ...           ...
# 373            121285179   TFCP2L1  tf_targeting
# 374            121285179   TFCP2L1  tf_targeting
# 375            121285179   TFCP2L1  tf_targeting
# 376            121285179   TFCP2L1  tf_targeting
# 377            121285179   TFCP2L1  tf_targeting
#
# [324 rows x 15 columns]

# %% [markdown]
# ## Spacers that I couldn't find in ref

# %%
# Find any spacers that do not match
mismatched_spacers = targeting_metadata[(~targeting_metadata["in_tf_ref"]) & (~targeting_metadata["in_nc_ref"])]
mismatched_spacers[["intended_target_name", "gene_name_gtf", "gene_name_mygene", "Photospacer"]]
# Out:
#     intended_target_name gene_name_gtf gene_name_mygene           Photospacer
# 60       ENSG00000074266           EED              EED  GCGAAGGAACGGGCCAATTG
# 61       ENSG00000074266           EED              EED  GGGGTCGGAGATCGAAGGAA
# 62       ENSG00000074266           EED              EED  GCTGAAACGTCTTTGGAAGG
# 63       ENSG00000074266           EED              EED  GGCAGCGGGTCGGAGATCGA
# 64       ENSG00000074266           EED              EED  GGTCTTTGGAAGGAGGAAGG
# ..                   ...           ...              ...                   ...
# 319      ENSG00000082014       SMARCD3          SMARCD3  GGAGTTTCTGGTCCATGGGG
# 320      ENSG00000082014       SMARCD3          SMARCD3  GGAGCCCAGCAGGACTCAGA
# 321      ENSG00000082014       SMARCD3          SMARCD3  GTCCATGGGGTGGTGAGTGG
# 322      ENSG00000082014       SMARCD3          SMARCD3  GCTCCCCTCTGAGTCCTGCT
# 323      ENSG00000082014       SMARCD3          SMARCD3  GAGGGCAAGCGAGCTGGCTC
#
# [61 rows x 4 columns]

# %%
mismatched_gene_name["intended_target_name"].isna().sum()
# Out:
# 0

# %%
mismatched_spacers["gene_name_mygene"].value_counts()
# Out:
# gene_name_mygene
# SMARCD3    12
# EED         6
# JARID2      6
# SMARCD1     6
# SMARCD2     6
# OR2D3       5
# OR4D6       5
# OR4X1       5
# OR6T1       5
# Name: count, dtype: int64

# %%
mismatched_spacers[mismatched_spacers["gene_name_mygene"] == "OR4X1"]
# Out:
#                        guide_id               spacer  targeting       type  \
# 192  chr11:48263880-48263898(+)  TGACTGAAATAATTTTCGT       True  targeting
# 193  chr11:48264090-48264108(-)  GAGTCAAAGATAAGCTTGG       True  targeting
# 194  chr11:48263953-48263971(-)  CACAACAGCTGTGTACATG       True  targeting
# 195  chr11:48264286-48264304(-)  GCCCCATGCTATCCTCACG       True  targeting
# 197  chr11:48264281-48264299(+)  CTCCTCGTGAGGATAGCAT       True  targeting
#
#     guide_chr  guide_start guide_end strand  PAM intended_target_name  ...  \
# 192     chr11     48263880  48263898      +  NGG      ENSG00000176567  ...
# 193     chr11     48264090  48264108      -  NGG      ENSG00000176567  ...
# 194     chr11     48263953  48263971      -  NGG      ENSG00000176567  ...
# 195     chr11     48264286  48264304      -  NGG      ENSG00000176567  ...
# 197     chr11     48264281  48264299      +  NGG      ENSG00000176567  ...
#
#               Photospacer        gene_id_gtf  gene_name_gtf overlap_length  \
# 192  GTGACTGAAATAATTTTCGT  ENSG00000176567.1          OR4X1          424.0
# 193  GGAGTCAAAGATAAGCTTGG  ENSG00000176567.1          OR4X1          424.0
# 194  GCACAACAGCTGTGTACATG  ENSG00000176567.1          OR4X1          424.0
# 195  GGCCCCATGCTATCCTCACG  ENSG00000176567.1          OR4X1          424.0
# 197  GCTCCTCGTGAGGATAGCAT  ENSG00000176567.1          OR4X1          424.0
#
#     gene_name_mygene gene_name  in_tf_ref in_nc_ref is_OR_gene  \
# 192            OR4X1     OR4X1      False     False       True
# 193            OR4X1     OR4X1      False     False       True
# 194            OR4X1     OR4X1      False     False       True
# 195            OR4X1     OR4X1      False     False       True
# 197            OR4X1     OR4X1      False     False       True
#
#                          new_guide_id
# 192  OR4X1#chr11:48263880-48263898(+)
# 193  OR4X1#chr11:48264090-48264108(-)
# 194  OR4X1#chr11:48263953-48263971(-)
# 195  OR4X1#chr11:48264286-48264304(-)
# 197  OR4X1#chr11:48264281-48264299(+)
#
# [5 rows x 23 columns]

# %% [markdown]
# # Make a final metadata table

# %%
print(f"Positive controls: {len(pc_clean_metadata)}, Non-targeting controls: {len(nt_clean_metadata)}, Negative controls: {len(nc_clean_metadata)}, Targeting guides: {len(tf_clean_metadata)}")
print(f"Total: {len(pc_clean_metadata) + len(nt_clean_metadata) + len(nc_clean_metadata) + len(tf_clean_metadata)}")
# Out:
# Positive controls: 7, Non-targeting controls: 30, Negative controls: 54, Targeting guides: 324
# Total: 415

# %%
# Make final metadata
final_metadata = pd.concat([pc_clean_metadata, nt_clean_metadata, nc_clean_metadata, tf_clean_metadata], ignore_index=True)

# Make sure all coordinates are integers or NaN
cols = ["guide_start", "guide_end", "intended_target_start", "intended_target_end"]
for c in cols:
    final_metadata[c] = (
        pd.to_numeric(final_metadata[c], errors="coerce")  # convert to numeric, set invalid to NaN
        .astype("Int64")                                   # use pandas nullable int type
    )

# %%
# If intendend_target_name has .suffix, remove the suffix
final_metadata["intended_target_name"] = final_metadata["intended_target_name"].str.split(".").str[0]

# %%
# Check that guide_chr matches intended_target_chr
(final_metadata['guide_chr'] == final_metadata['intended_target_chr']).sum()
# Out:
# 385

# %%
final_metadata[(final_metadata['guide_chr'] != final_metadata['intended_target_chr'])]["label"].value_counts()
# Out:
# label
# non_targeting    30
# Name: count, dtype: int64

# %%
# - ENSG00000291901 -> ENSG00000196266  # Olfatory gene, the ensembl ID linked is found in a chrom patch 
# - ENSBTSG00005026991 -> ENSG00000166681 # Not found, inferred from gene symbol
# - ENSSDUG00000003529 -> ENSG00000133794 # Not found, inferred from gene symbol
final_metadata.loc[final_metadata['intended_target_name'] == 'ENSG00000291901', 'intended_target_name'] = 'ENSG00000196266'
final_metadata.loc[final_metadata['intended_target_name'] == 'ENSBTSG00005026991', 'intended_target_name'] = 'ENSG00000166681'
final_metadata.loc[final_metadata['intended_target_name'] == 'ENSSDUG00000003529', 'intended_target_name'] = 'ENSG00000133794'

# %%
final_metadata.to_csv("/cellar/users/aklie/data/datasets/tf_perturb_seq/scratch/2025_10_05/benchmark_guide_metadata.tsv", sep="\t", index=False)

# %% [markdown]
# # DONE!

# %% [markdown]
# ---

# %%
path_ref_nc_metadata = "/cellar/users/aklie/data/datasets/tf_perturb_seq/ref/negative_controls.tsv"
spacer_cols = ['Photospacer 1', 'Photospacer 2', 'Photospacer 3', 'Photospacer 4', 'Photospacer 5', 'Photospacer 6']
ref_nc = pd.read_csv(path_ref_nc_metadata, sep="\t")
for col in spacer_cols:
    ref_nc[col] = ref_nc[col].str.upper()

# Melt the dataframe into long format
ref_nc_long = ref_nc.melt(
    id_vars=["Gene"],
    value_vars=[col for col in ref_nc.columns if col.startswith("Photospacer")],
    var_name="Photospacer_label",
    value_name="Photospacer"
)

# Extract the numeric part of the photospacer label
ref_nc_long["Photospacer_number"] = (
    ref_nc_long["Photospacer_label"]
    .str.extract(r"(\d+)").astype(int)
)

# Create guide_id
ref_nc_long["guide_id"] = ref_nc_long.apply(lambda x: f"{x['Gene']}#Set_A#Photospacer_{x['Photospacer_number']}", axis=1)
ref_nc_long = ref_nc_long[["Gene", "Photospacer", "Photospacer_number", "guide_id"]]
ref_nc_long.head()
