# %%
import anndata as ad
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
hon = ad.read_h5ad("/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/gene.filtered.h5ad")

# %%
hon.obs
# Out:
#                              batch  cov1  batch_number  n_counts  \
# CCTATTAGTCCTCTTG_0  IGVFDS6244NAXC     1             1      3718
# CTTTGCGAGTCAAGGC_0  IGVFDS6244NAXC     1             1      2897
# GTAGTCAGTCTGGTCG_0  IGVFDS6244NAXC     1             1      2240
# GCAATCAAGTCGTACT_0  IGVFDS6244NAXC     1             1      4567
# CCCAATCAGACGACGT_0  IGVFDS6244NAXC     1             1      1743
# ...                            ...   ...           ...       ...
# CCACTACGTAAATGTG_3  IGVFDS9613DDRB     1             4      2716
# GCTCTGTGTGGTAACG_3  IGVFDS9613DDRB     1             4       870
# GGAAAGCGTACTTAGC_3  IGVFDS9613DDRB     1             4      2043
# TACAGTGCAAGCGATG_3  IGVFDS9613DDRB     1             4      2770
# TACAGTGTCTCTAGGA_3  IGVFDS9613DDRB     1             4      2124
#
#                     log1p_n_genes_by_counts  total_gene_umis  \
# CCTATTAGTCCTCTTG_0                 8.221210           8116.0
# ...

# %%
merged = ad.read_h5ad("/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/technology-benchmark_WTC11_TF-Perturb-seq/results/merge/merge.h5ad")

# %%
merged.obs
# Out:
#                                                              batch  cov1  \
# Hon_WTC11-benchmark_TF-Perturb-seq#CCTATTAGTCCT...  IGVFDS6244NAXC     1
# Hon_WTC11-benchmark_TF-Perturb-seq#CTTTGCGAGTCA...  IGVFDS6244NAXC     1
# Hon_WTC11-benchmark_TF-Perturb-seq#GTAGTCAGTCTG...  IGVFDS6244NAXC     1
# Hon_WTC11-benchmark_TF-Perturb-seq#GCAATCAAGTCG...  IGVFDS6244NAXC     1
# Hon_WTC11-benchmark_TF-Perturb-seq#CCCAATCAGACG...  IGVFDS6244NAXC     1
# ...                                                            ...   ...
# Gersbach_WTC11-benchmark_TF-Perturb-seq_HTv2#TC...  IGVFDS6261TOSA     2
# Gersbach_WTC11-benchmark_TF-Perturb-seq_HTv2#GT...  IGVFDS6261TOSA     2
# Gersbach_WTC11-benchmark_TF-Perturb-seq_HTv2#CC...  IGVFDS6261TOSA     2
# Gersbach_WTC11-benchmark_TF-Perturb-seq_HTv2#CG...  IGVFDS6261TOSA     2
# Gersbach_WTC11-benchmark_TF-Perturb-seq_HTv2#GT...  IGVFDS6261TOSA     2
#
#                                                     batch_number  n_counts  \
# ...
