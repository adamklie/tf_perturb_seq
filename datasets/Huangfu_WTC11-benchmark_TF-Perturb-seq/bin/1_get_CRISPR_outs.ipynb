# %% [markdown]
# # Set-up

# %%
# imports
import os
import sys
import synapseclient
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib_venn import venn3

# %%
path_out = "/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/1_CRISPR_pipeline/2026_01_12"

# %% [markdown]
# # Download

# %%
# Token
SYNAPSE_AUTH_TOKEN = os.environ.get('SYNAPSE_AUTH_TOKEN')

# %%
# Login
syn = synapseclient.Synapse() 
syn.login(authToken=SYNAPSE_AUTH_TOKEN)
# Out:
# UPGRADE AVAILABLE
#
# A more recent version of the Synapse Client (4.11.0) is available. Your version (2.7.2) can be upgraded by typing:
#     pip install --upgrade synapseclient
#
# Python Synapse Client version 4.11.0 release notes
#
# https://python-docs.synapse.org/news/
# Welcome, Adam Klie!

# %%
# Obtain a pointer and download the data 
syn.get(entity='syn72299991', downloadLocation=path_out)

# unzip it
os.system(f"unzip -o {path_out}/pipeline_dashboard.zip -d {path_out}")
# Out:
# Archive:  /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/1_CRISPR_pipeline/2026_01_12/pipeline_dashboard.zip
#    creating: /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/1_CRISPR_pipeline/2026_01_12/pipeline_dashboard/
#    creating: /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/1_CRISPR_pipeline/2026_01_12/pipeline_dashboard/evaluation_output/
#   inflating: /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/1_CRISPR_pipeline/2026_01_12/pipeline_dashboard/evaluation_output/trans_perturbo_barplot_direct_vs_control.png
#  extracting: /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/1_CRISPR_pipeline/2026_01_12/pipeline_dashboard/evaluation_output/cis_sceptre.bedgraph
# ...

# %% [markdown]
# # DONE!

# %% [markdown]
# ---
