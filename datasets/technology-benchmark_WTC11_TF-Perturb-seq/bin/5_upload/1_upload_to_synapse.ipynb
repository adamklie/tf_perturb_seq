# %% [markdown]
# # Set-up

# %%
# imports
import os
import sys
import synapseclient
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %% [markdown]
# # Login

# %%
# Token
SYNAPSE_AUTH_TOKEN = os.environ.get('SYNAPSE_AUTH_TOKEN')

# %%
# Login
syn = synapseclient.Synapse() 
syn.login(authToken=SYNAPSE_AUTH_TOKEN)
# Out:
# UPGRADE AVAILABLE
#
# A more recent version of the Synapse Client (4.11.0) is available. Your version (2.7.2) can be upgraded by typing:
#     pip install --upgrade synapseclient
#
# Python Synapse Client version 4.11.0 release notes
#
# https://python-docs.synapse.org/news/
# Welcome, Adam Klie!

# %% [markdown]
# # Upload

# %%
project_id = "syn64423137"

# %%
datasets = [
    "Gersbach_WTC11-benchmark_TF-Perturb-seq_GEM-Xv3",
    "Gersbach_WTC11-benchmark_TF-Perturb-seq_HTv2",
    "Hon_WTC11-benchmark_TF-Perturb-seq",
    "Huangfu_WTC11-benchmark_TF-Perturb-seq",
]

base = "/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets"


def get_children_map(parent_id):
    """Return {name: id} for direct children of a Synapse folder/project."""
    return {c["name"]: c["id"] for c in syn.getChildren(parent_id)}


def get_or_create_folder(parent_id, name):
    """Get a folder by name under parent_id, or create it if it doesn't exist."""
    children = get_children_map(parent_id)
    if name in children:
        return syn.get(children[name])
    return syn.store(synapseclient.Folder(name=name, parent=parent_id))


def mirror_to_synapse(local_root, syn_parent):
    """
    Recursively mirror local_root directory structure into Synapse folder syn_parent.
    local_root itself is *not* created as a folder; its contents are.
    """
    folder_map = {local_root: syn_parent}

    for dirpath, dirnames, filenames in os.walk(local_root):
        parent_id = folder_map[dirpath]

        # Create subfolders
        for d in dirnames:
            local_subdir = os.path.join(dirpath, d)
            syn_subfolder = syn.store(
                synapseclient.Folder(name=d, parent=parent_id)
            )
            folder_map[local_subdir] = syn_subfolder["id"]

        # Upload files
        for fname in filenames:
            local_file = os.path.join(dirpath, fname)
            syn_file = synapseclient.File(path=local_file, parent=parent_id)
            syn.store(syn_file)


# ---- Map existing top-level dataset folders under the project ----
top_level_children = get_children_map(project_id)

for dataset in datasets:
    dataset_dir = os.path.join(base, dataset)
    qc_dir = os.path.join(dataset_dir, "results", "2_qc")

    if not os.path.isdir(qc_dir):
        print(f"Skipping {dataset}: local qc directory missing at {qc_dir}")
        continue

    if dataset not in top_level_children:
        print(f"Skipping {dataset}: no matching folder under {project_id} on Synapse")
        continue

    dataset_syn_id = top_level_children[dataset]
    print(f"Uploading QC tree for dataset: {dataset} -> Synapse folder {dataset_syn_id}")

    # Ensure results/ and 2_qc/ folders exist under the dataset folder
    results_folder = get_or_create_folder(dataset_syn_id, "results")
    qc_folder = get_or_create_folder(results_folder["id"], "2_qc")

    # Mirror contents of local results/2_qc into Synapse results/2_qc
    mirror_to_synapse(qc_dir, qc_folder["id"])

    print(f"Finished uploading {dataset}")
# Out:
# Uploading QC tree for dataset: Gersbach_WTC11-benchmark_TF-Perturb-seq_GEM-Xv3 -> Synapse folder syn70110613
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# Finished uploading Gersbach_WTC11-benchmark_TF-Perturb-seq_GEM-Xv3
# Uploading QC tree for dataset: Gersbach_WTC11-benchmark_TF-Perturb-seq_HTv2 -> Synapse folder syn70110612
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# Finished uploading Gersbach_WTC11-benchmark_TF-Perturb-seq_HTv2
# Uploading QC tree for dataset: Hon_WTC11-benchmark_TF-Perturb-seq -> Synapse folder syn70110603
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################

# %%
dataset_name = "technology-benchmark_WTC11_TF-Perturb-seq"
local_results_dir = (
    "/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/"
    "technology-benchmark_WTC11_TF-Perturb-seq/results"
)


def get_children_map(parent_id):
    """Return {name: id} for direct child folders of a Synapse container."""
    return {c["name"]: c["id"] for c in syn.getChildren(parent_id)}


def get_or_create_folder(parent_id, name):
    """Get a Synapse folder by name, or create it under parent_id."""
    children = get_children_map(parent_id)
    if name in children:
        return syn.get(children[name])
    return syn.store(synapseclient.Folder(name=name, parent=parent_id))


def mirror_to_synapse(local_root, syn_parent):
    """
    Recursively mirror the entire local directory tree starting at local_root
    *into* Synapse under syn_parent.
    """
    folder_map = {local_root: syn_parent}

    for dirpath, dirnames, filenames in os.walk(local_root):
        parent_id = folder_map[dirpath]

        # Create folders
        for d in dirnames:
            local_subdir = os.path.join(dirpath, d)
            syn_subfolder = syn.store(
                synapseclient.Folder(name=d, parent=parent_id)
            )
            folder_map[local_subdir] = syn_subfolder["id"]

        # Upload files
        for fname in filenames:
            file_path = os.path.join(dirpath, fname)
            syn_file = synapseclient.File(path=file_path, parent=parent_id)
            syn.store(syn_file)


# ============================ RUN UPLOAD ============================

# Ensure the dataset folder exists at the project top level
top_children = get_children_map(project_id)

if dataset_name not in top_children:
    raise ValueError(
        f"No folder named '{dataset_name}' under project {project_id}. "
        "Create it manually or correct the name."
    )

dataset_syn_id = top_children[dataset_name]

# Create or reuse dataset/results folder
results_folder = get_or_create_folder(dataset_syn_id, "results")

# Mirror the entire local results tree
print(f"Uploading entire results tree from {local_results_dir}")
mirror_to_synapse(local_results_dir, results_folder["id"])
print("Upload complete!")
# Out:
# Uploading entire results tree from /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/technology-benchmark_WTC11_TF-Perturb-seq/results
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# ✓ Upload complete!

# %%
import os
import hashlib
import synapseclient

# ---------------------------
# Helpers
# ---------------------------

def get_children_map(parent_id):
    """Return {name: id} for direct children of a Synapse folder/project."""
    return {c["name"]: c["id"] for c in syn.getChildren(parent_id)}

def get_or_create_folder_id(parent_id, name):
    """Get a folder by name under parent_id, or create it if it doesn't exist. Returns folder id."""
    children = get_children_map(parent_id)
    if name in children:
        return children[name]
    folder = syn.store(synapseclient.Folder(name=name, parent=parent_id))
    return folder["id"]

def md5_file(path, chunk_size=1024 * 1024):
    h = hashlib.md5()
    with open(path, "rb") as f:
        for chunk in iter(lambda: f.read(chunk_size), b""):
            h.update(chunk)
    return h.hexdigest()

def get_remote_file_md5(file_entity_id):
    """
    Return Synapse-stored MD5 for the current version of a File entity.
    Does not download the file.
    """
    ent = syn.get(file_entity_id, downloadFile=False)
    # Synapse File entity has 'md5' in properties for the file handle in most contexts
    # (If this ever returns None in your environment, we can fall back to fileHandles API.)
    return ent.properties.get("md5")

# ---------------------------
# Incremental mirroring
# ---------------------------

def mirror_to_synapse_incremental(local_root, syn_parent_id, *, compare_md5=False, verbose=True):
    """
    Recursively mirror local_root directory structure into Synapse folder syn_parent_id.
    Only uploads files that do NOT already exist by name in the destination folder.
    If compare_md5=True, uploads only when the existing file's MD5 differs.
    """
    # Map local dir -> syn folder id
    folder_map = {os.path.abspath(local_root): syn_parent_id}

    for dirpath, dirnames, filenames in os.walk(local_root):
        dirpath = os.path.abspath(dirpath)
        parent_syn_id = folder_map[dirpath]

        # Create/reuse subfolders (no duplicates)
        # Note: keep os.walk from descending into dirs you might want to skip by editing dirnames in-place.
        for d in dirnames:
            local_subdir = os.path.join(dirpath, d)
            syn_sub_id = get_or_create_folder_id(parent_syn_id, d)
            folder_map[os.path.abspath(local_subdir)] = syn_sub_id

        # Build one-time map of existing children under this Synapse folder
        syn_children = get_children_map(parent_syn_id)  # name -> id

        # Upload only missing / changed files
        for fname in filenames:
            local_file = os.path.join(dirpath, fname)
            if not os.path.isfile(local_file):
                continue

            if fname in syn_children:
                # Something with same name exists (could be File or Folder; skip either way)
                existing_id = syn_children[fname]

                if compare_md5:
                    try:
                        remote_md5 = get_remote_file_md5(existing_id)
                    except Exception:
                        remote_md5 = None

                    local_md5 = md5_file(local_file)

                    if remote_md5 and remote_md5.lower() == local_md5.lower():
                        if verbose:
                            print(f"SKIP (same md5): {local_file}")
                        continue
                    else:
                        # If same name exists but different content, you need a policy:
                        # (a) skip, (b) upload as a NEW entity w/ different name, or (c) update version.
                        # Here we update the existing File entity by storing with its id.
                        if verbose:
                            print(f"UPDATE (md5 differs): {local_file} -> {existing_id}")
                        f_ent = synapseclient.File(path=local_file, parent=parent_syn_id)
                        f_ent.id = existing_id
                        syn.store(f_ent, forceVersion=True)  # creates a new version
                        continue

                if verbose:
                    print(f"SKIP (exists): {local_file}")
                continue

            # New file by name -> upload
            if verbose:
                print(f"UPLOAD (new): {local_file}")
            syn_file = synapseclient.File(path=local_file, parent=parent_syn_id)
            syn.store(syn_file)

# %%
# ---------------------------
# Your loop (minimal changes)
# ---------------------------

datasets = [
    #"Gersbach_WTC11-benchmark_TF-Perturb-seq_GEM-Xv3",
    #"Gersbach_WTC11-benchmark_TF-Perturb-seq_HTv2",
    "Hon_WTC11-benchmark_TF-Perturb-seq",
    "Huangfu_WTC11-benchmark_TF-Perturb-seq",
]

base = "/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets"

top_level_children = get_children_map(project_id)

for dataset in datasets:
    dataset_dir = os.path.join(base, dataset)
    qc_dir = os.path.join(dataset_dir, "results", "2_qc")

    if not os.path.isdir(qc_dir):
        print(f"Skipping {dataset}: local qc directory missing at {qc_dir}")
        continue

    if dataset not in top_level_children:
        print(f"Skipping {dataset}: no matching folder under {project_id} on Synapse")
        continue

    dataset_syn_id = top_level_children[dataset]
    print(f"Uploading QC tree for dataset: {dataset} -> Synapse folder {dataset_syn_id}")

    # Ensure results/ and 2_qc/ folders exist under the dataset folder
    results_id = get_or_create_folder_id(dataset_syn_id, "results")
    qc_id = get_or_create_folder_id(results_id, "2_qc")

    # Incremental mirror
    mirror_to_synapse_incremental(qc_dir, qc_id, compare_md5=False, verbose=True)
    # If you want “only upload when content differs”, use:
    # mirror_to_synapse_incremental(qc_dir, qc_id, compare_md5=True, verbose=True)

    print(f"Finished uploading {dataset}")
# Out:
# Uploading QC tree for dataset: Hon_WTC11-benchmark_TF-Perturb-seq -> Synapse folder syn70110603
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/pre_filter_guide_qc.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/pre_filter_gene_knee_plot.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/gene.filtered.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/post_filter_gene_qc_histograms_by_batch.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/guide.filtered.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/post_filter_guide_knee_plot.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/qc_metrics.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/pre_filter_gene_qc_histograms_by_batch.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/pre_filter_cells_per_batch.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/post_filter_guide_qc.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/pre_filter_guide_knee_plot.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/post_filter_gene_knee_plot.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/post_filter_cells_per_batch.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_results.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_results.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_strong-knockdowns-fc-0.4.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_strong_knockdowns.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_volcano.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_significant.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_volcano.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_significant-pval-0.05.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/clustering/clustering.log
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/clustering/gene.clustered.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/clustering/umap_clustering.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/preprocess/gene.preprocessed.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/preprocess/preprocess.log
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/preprocess/highly_variable_genes.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_results.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_significant.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_volcano.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_results.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_strong-knockdowns-fc-0.4.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_strong_knockdowns.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_significant-pval-0.05.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_volcano.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/pre_filter_cells_per_batch.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/pre_filter_guide_qc.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/post_filter_cells_per_batch.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/guide.filtered.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/post_filter_gene_qc_histograms_by_batch.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/pre_filter_gene_qc_histograms_by_batch.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/post_filter_guide_qc.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/post_filter_gene_knee_plot.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/post_filter_guide_knee_plot.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/pre_filter_guide_knee_plot.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/pre_filter_gene_knee_plot.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/qc_metrics.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/mapping_qc/gene.filtered.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/clustering/clustering.log
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/clustering/umap_clustering.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/clustering/gene.clustered.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/preprocess/highly_variable_genes.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/preprocess/preprocess.log
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_05/preprocess/gene.preprocessed.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW589_IGVFDS8721BKRO/LW589_hto_matrix_featurecount.csv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW589_IGVFDS8721BKRO/LW589_hto_feature_barcoding_output.tsv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW589_IGVFDS8721BKRO/final_combined_sgRNA_multiplets_HTO_singlets.pkl
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW589_IGVFDS8721BKRO/LW589_sgrna_matrix_featurecount.csv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW589_IGVFDS8721BKRO/HTO_Singlets_DF.pkl
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW589_IGVFDS8721BKRO/LW589_sgrna_feature_barcoding_output.tsv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW589_IGVFDS8721BKRO/sgRNA_DF_sgDropNaN.pkl
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW590_IGVFDS9613DDRB/HTO_Singlets_DF.pkl
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW590_IGVFDS9613DDRB/LW590_sgrna_matrix_featurecount.csv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW590_IGVFDS9613DDRB/LW590_hto_feature_barcoding_output.tsv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW590_IGVFDS9613DDRB/sgRNA_DF_sgDropNaN.pkl
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW590_IGVFDS9613DDRB/LW590_hto_matrix_featurecount.csv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW590_IGVFDS9613DDRB/LW590_sgrna_feature_barcoding_output.tsv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW590_IGVFDS9613DDRB/final_combined_sgRNA_multiplets_HTO_singlets.pkl
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW591_IGVFDS6244NAXC/HTO_Singlets_DF.pkl
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW591_IGVFDS6244NAXC/final_combined_sgRNA_multiplets_HTO_singlets.pkl
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW591_IGVFDS6244NAXC/LW591_hto_matrix_featurecount.csv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW591_IGVFDS6244NAXC/LW591_sgrna_matrix_featurecount.csv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW591_IGVFDS6244NAXC/sgRNA_DF_sgDropNaN.pkl
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW591_IGVFDS6244NAXC/LW591_hto_feature_barcoding_output.tsv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW591_IGVFDS6244NAXC/LW591_sgrna_feature_barcoding_output.tsv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW588_IGVFDS9332KWPJ/LW588_sgrna_matrix_featurecount.csv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW588_IGVFDS9332KWPJ/final_combined_sgRNA_multiplets_HTO_singlets.pkl
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW588_IGVFDS9332KWPJ/LW588_hto_matrix_featurecount.csv.gz
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW588_IGVFDS9332KWPJ/HTO_Singlets_DF.pkl
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW588_IGVFDS9332KWPJ/LW588_sgrna_feature_barcoding_output.tsv.gz
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW588_IGVFDS9332KWPJ/LW588_hto_feature_barcoding_output.tsv.gz
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW588_IGVFDS9332KWPJ/sgRNA_DF_sgDropNaN.pkl
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/filtered_feature_bc_matrix.h5
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/qc.log
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/qc.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/anndata.log
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/cluster.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/anndata.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/cluster.log
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/preprocess.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/preprocess.log
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/plots/cluster/umap_clustering.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/plots/qc/violin_n_genes.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/plots/qc/total_counts_vs_n_genes.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/plots/qc/total_counts_vs_pct_MT.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/plots/qc/violin_total_counts.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/plots/qc/violin_pct_MT.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/CellRanger_qc/plots/preprocess/highly_variable_genes.png
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_11/lane_qc_summary.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_11/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_significant.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_11/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_significant-pval-0.05.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_11/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_volcano.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_11/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_results.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_11/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_results.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_11/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_volcano.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_11/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_strong_knockdowns.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_11/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_strong-knockdowns-fc-0.4.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_guide/Hon_WTC11-benchmark_TF-Perturb-seq_guide_metrics.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_guide/Hon_WTC11-benchmark_TF-Perturb-seq_guide_histograms_by_batch.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_guide/Hon_WTC11-benchmark_TF-Perturb-seq_guide_histograms.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_guide/Hon_WTC11-benchmark_TF-Perturb-seq_guide_knee_plot.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_gene/Hon_WTC11-benchmark_TF-Perturb-seq_gene_metrics.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_gene/Hon_WTC11-benchmark_TF-Perturb-seq_gene_histograms_by_batch.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_gene/Hon_WTC11-benchmark_TF-Perturb-seq_gene_knee_plot.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_gene/Hon_WTC11-benchmark_TF-Perturb-seq_gene_cells_per_batch.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_gene/Hon_WTC11-benchmark_TF-Perturb-seq_gene_histograms.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/trans/Hon_WTC11-benchmark_TF-Perturb-seq_trans_volcano.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/trans/Hon_WTC11-benchmark_TF-Perturb-seq_trans_metrics.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/trans/Hon_WTC11-benchmark_TF-Perturb-seq_trans_per_guide_distribution.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/trans/Hon_WTC11-benchmark_TF-Perturb-seq_trans_significant_results.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/trans/Hon_WTC11-benchmark_TF-Perturb-seq_trans_per_guide_summary.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/trans/Hon_WTC11-benchmark_TF-Perturb-seq_trans_results.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/intended_target/Hon_WTC11-benchmark_TF-Perturb-seq_intended_target_metrics.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/intended_target/Hon_WTC11-benchmark_TF-Perturb-seq_intended_target_volcano.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/intended_target/Hon_WTC11-benchmark_TF-Perturb-seq_intended_target_log2fc_distribution.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/intended_target/Hon_WTC11-benchmark_TF-Perturb-seq_intended_target_results.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/intended_target/Hon_WTC11-benchmark_TF-Perturb-seq_intended_target_roc_pr_curves.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/post_filter_gene_qc_histograms_by_batch.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/pre_filter_guide_qc.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/post_filter_gene_knee_plot.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/guide.filtered.h5ad
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/pre_filter_gene_qc_histograms_by_batch.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/post_filter_cells_per_batch.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/pre_filter_guide_knee_plot.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/pre_filter_cells_per_batch.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/post_filter_guide_knee_plot.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/pre_filter_gene_knee_plot.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/gene.filtered.h5ad
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/post_filter_guide_qc.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/mapping_qc/qc_metrics.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/clustering/umap_clustering.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/clustering/clustering.log
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/clustering/gene.clustered.h5ad
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/preprocess/gene.preprocessed.h5ad
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/preprocess/highly_variable_genes.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/preprocess/preprocess.log
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_results.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_17/inference_qc/Hon_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_volcano.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# Finished uploading Hon_WTC11-benchmark_TF-Perturb-seq
# Uploading QC tree for dataset: Huangfu_WTC11-benchmark_TF-Perturb-seq -> Synapse folder syn70110609
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_gene/Huangfu_WTC11-benchmark_TF-Perturb-seq_gene_cells_per_batch.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_gene/Huangfu_WTC11-benchmark_TF-Perturb-seq_gene_histograms.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_gene/Huangfu_WTC11-benchmark_TF-Perturb-seq_gene_metrics.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_gene/Huangfu_WTC11-benchmark_TF-Perturb-seq_gene_histograms_by_batch.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_gene/Huangfu_WTC11-benchmark_TF-Perturb-seq_gene_knee_plot.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/trans/Huangfu_WTC11-benchmark_TF-Perturb-seq_trans_volcano.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/trans/Huangfu_WTC11-benchmark_TF-Perturb-seq_trans_metrics.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/trans/Huangfu_WTC11-benchmark_TF-Perturb-seq_trans_significant_results.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/trans/Huangfu_WTC11-benchmark_TF-Perturb-seq_trans_per_guide_distribution.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/trans/Huangfu_WTC11-benchmark_TF-Perturb-seq_trans_per_guide_summary.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/trans/Huangfu_WTC11-benchmark_TF-Perturb-seq_trans_results.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/intended_target/Huangfu_WTC11-benchmark_TF-Perturb-seq_intended_target_results.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/intended_target/Huangfu_WTC11-benchmark_TF-Perturb-seq_intended_target_log2fc_distribution.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/intended_target/Huangfu_WTC11-benchmark_TF-Perturb-seq_intended_target_metrics.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/intended_target/Huangfu_WTC11-benchmark_TF-Perturb-seq_intended_target_volcano.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/intended_target/Huangfu_WTC11-benchmark_TF-Perturb-seq_intended_target_roc_pr_curves.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_guide/Huangfu_WTC11-benchmark_TF-Perturb-seq_guide_histograms.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_guide/Huangfu_WTC11-benchmark_TF-Perturb-seq_guide_metrics.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_guide/Huangfu_WTC11-benchmark_TF-Perturb-seq_guide_knee_plot.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2026_01_14/mapping_guide/Huangfu_WTC11-benchmark_TF-Perturb-seq_guide_histograms_by_batch.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/inference_qc/Huangfu_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_results.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/inference_qc/Huangfu_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_strong-knockdowns-fc-0.4.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/inference_qc/Huangfu_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_significant-pval-0.05.tsv
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# UPLOAD (new): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/inference_qc/Huangfu_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_volcano.png
#
# ##################################################
#  Uploading file to Synapse storage
# ##################################################
#
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/preprocess/preprocess.log
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/preprocess/highly_variable_genes.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/preprocess/gene.preprocessed.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Huangfu_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_strong_knockdowns.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Huangfu_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_volcano.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Huangfu_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_volcano.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Huangfu_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_significant.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Huangfu_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_significant-pval-0.05.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Huangfu_WTC11-benchmark_TF-Perturb-seq_perturbo-trans-intended-target_results.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Huangfu_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_strong-knockdowns-fc-0.4.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/inference_qc/Huangfu_WTC11-benchmark_TF-Perturb-seq_perturbo-cis-intended-target_results.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/pre_filter_cells_per_batch.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/pre_filter_guide_qc.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/post_filter_gene_qc_histograms_by_batch.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/qc_metrics.tsv
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/pre_filter_guide_knee_plot.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/post_filter_gene_knee_plot.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/gene.filtered.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/post_filter_guide_knee_plot.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/pre_filter_gene_qc_histograms_by_batch.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/pre_filter_gene_knee_plot.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/post_filter_guide_qc.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/guide.filtered.h5ad
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/mapping_qc/post_filter_cells_per_batch.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/clustering/clustering.log
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/clustering/umap_clustering.png
# SKIP (exists): /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Huangfu_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_01/clustering/gene.clustered.h5ad
# Finished uploading Huangfu_WTC11-benchmark_TF-Perturb-seq
