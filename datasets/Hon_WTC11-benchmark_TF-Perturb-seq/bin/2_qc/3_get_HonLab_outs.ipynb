# %% [markdown]
# # Set-up

# %%
# imports
import os
import sys
import pickle
import synapseclient
import numpy as np
import pandas as pd
import scanpy as sc
import mudata
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib_venn import venn3
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
path_out = "/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16"

# %% [markdown]
# # Download

# %%
# Token
SYNAPSE_AUTH_TOKEN = os.environ.get('SYNAPSE_AUTH_TOKEN')

# %%
# Login
syn = synapseclient.Synapse() 
syn.login(authToken="eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..cTODBdjapDV3gbVnZZ-ePa5VmLnMfNJYlYlTHDFfV84EMe9Rz9Pu5KeR2dGlsBCvboNBt5dXGxtDHtxOhVspYjAYtbVOtx7Muea5S_2EiDGWdrmGUNwRwdRtwZGw3FBgoysaWk_NVxL0rfrQAgXTMdDRzHS0suAm2ygoDVkTGkfezxPbGwUsWuIZLO_LT979v-9JsIsFYMP830oSKA2GVfUloORfoLpG9cyn00hmmKNrHPw-IkYScXzd1zgW5PzqgrphdE1orgB9KLl8mCChS8l7PZ4xObauaVNHLAuiKNs_PLHPRftcGnjo6eheNPq3IsPRVy7sjVZ9OhTZ7AY-rQ")
# Out:
# Welcome, Adam Klie!

# %% [markdown]
# # CellRanger outs

# %%
# Obtain a pointer and download the data 
#syn = syn.get(entity='syn71824399', downloadLocation=path_out)
 
# Get the path to the local copy of the data file 
#filepath = syn.path 
filepath = "/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_02/filtered_feature_bc_matrix.h5"

# %%
adata = sc.read_10x_h5(filepath)

# %% [markdown]
# # FBA outs

# %%
from synapseclient.models import Project, Folder

# %%
# Download all the subdirs in this parent directory: syn71857614
# But we need to respect the structure of the subdirs
folder = Folder('syn71857614')
folder.sync_from_synapse(path=path_out)
# Out:
# ...
# [syn71857614:FBA_outputs]: Syncing Folder from Synapse.
# ...
# [syn71857615:LW588_IGVFDS9332KWPJ]: Syncing Folder from Synapse.
# ...
# [syn71857619:LW590_IGVFDS9613DDRB]: Syncing Folder from Synapse.
# ...
# [syn71857620:LW591_IGVFDS6244NAXC]: Syncing Folder from Synapse.
# ...
# [syn71857618:LW589_IGVFDS8721BKRO]: Syncing Folder from Synapse.
# ...
# [syn71857628:HTO_Singlets_DF.pkl]: Found existing file at /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW588_IGVFDS9332KWPJ/HTO_Singlets_DF.pkl, skipping download.
# ...
# [syn71857629:LW588_sgrna_matrix_featurecount.csv.gz]: Found existing file at /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW588_IGVFDS9332KWPJ/LW588_sgrna_matrix_featurecount.csv.gz, skipping download.
# ...

# %%
path_sgRNA_mtx = "/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW588_IGVFDS9332KWPJ/LW588_sgrna_matrix_featurecount.csv.gz"
sgRNA_mtx = pd.read_csv(path_sgRNA_mtx, index_col=0)

# %%
sgRNA_mtx
# Out:
#                                          AAACCTGAGAATAGGG  AAACCTGAGAATTGTG  \
# CD151:1_ACCACGCGTCCGAGTCCGG                            13                 0
# CD151:2_CGACAGCTCGGCCGAGCGG                             8                 4
# CD55_GGACTCCGCCGAGTCGCAG                               15                 3
# CD81:1_CCGTTGCGCGCTCGCTCTC                              1                 5
# CD81:2_CCGTTGCGCGCTGGCTCTC                             61                 4
# ...                                                   ...               ...
# non-targeting_03484_CGCGGTGTTGCCGACACCC                 0                 0
# non-targeting_03631_ACGTTCTTGCAGACGCGTC                 3                 0
# non-targeting_03639_GGTTACGGCGTGGCGGGCC                 4                 1
# non-targeting_03705_CGTGCCGCGGGTCCATGCC                 1                 5
# non-targeting_03783_TGTCGTTCGATCCTAGCTC                 2                 0
#
# ...

# %%
path_pickle = "/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW588_IGVFDS9332KWPJ/sgRNA_DF_sgDropNaN.pkl"

# %%
sgrna_df = pd.read_pickle(path_pickle)
sgrna_df
# Out:
#                                          AAACCTGAGAATAGGG-1  \
# CD151:1_ACCACGCGTCCGAGTCCGG                              13
# CD151:2_CGACAGCTCGGCCGAGCGG                               8
# CD55_GGACTCCGCCGAGTCGCAG                                 15
# CD81:1_CCGTTGCGCGCTCGCTCTC                                1
# CD81:2_CCGTTGCGCGCTGGCTCTC                               61
# ...                                                     ...
# non-targeting_03484_CGCGGTGTTGCCGACACCC                   0
# non-targeting_03631_ACGTTCTTGCAGACGCGTC                   3
# non-targeting_03639_GGTTACGGCGTGGCGGGCC                   4
# non-targeting_03705_CGTGCCGCGGGTCCATGCC                   1
# non-targeting_03783_TGTCGTTCGATCCTAGCTC                   2
#
#                                          AAACCTGAGAATTGTG-1  \
# CD151:1_ACCACGCGTCCGAGTCCGG                               0
# CD151:2_CGACAGCTCGGCCGAGCGG                               4
# CD55_GGACTCCGCCGAGTCGCAG                                  3
# ...

# %%
path_assignment_mtx = "/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/Hon_WTC11-benchmark_TF-Perturb-seq/results/2_qc/2025_12_16/LW589_IGVFDS8721BKRO/final_combined_sgRNA_multiplets_HTO_singlets.pkl"
assignment_mtx = pd.read_pickle(path_assignment_mtx)

# %%
# Out:
# array([[False, False,  True, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
# Calculate the number of non-zero columns in each row
num_guides_per_cell = pd.Series(np.sum(assignment_mtx.values > 0, axis=1), index=assignment_mtx.index)
num_guides_per_cell
# Out:
# AAACCTGAGAACAACT-1    1
# AAACCTGAGAAGAAGC-1    2
# AAACCTGAGACTACAA-1    3
# AAACCTGAGAGTTGGC-1    1
# AAACCTGAGCAGATCG-1    1
#                      ..
# TTTGTCATCCGTAGTA-1    2
# TTTGTCATCCTTGACC-1    1
# TTTGTCATCGAGGTAG-1    1
# TTTGTCATCGGAAATA-1    1
# TTTGTCATCTGCTTGC-1    1
# Length: 22413, dtype: int64

# %%
# Plot the distribution
plt.figure(figsize=(8,4))
sns.histplot(num_guides_per_cell, bins=30, kde=False)
plt.xlabel("Number of guides assigned per cell")
# Out:
# Text(0.5, 0, 'Number of guides assigned per cell')

# %%
# median
num_guides_per_cell.mean()
# Out:
# 2.0262347744612503
