# %% [markdown]
# # Pipeline Comparison
#
# This notebook adds new pipeline metrics to the tracker TSV and optionally generates comparison plots.

# %%
# imports
import os
from datetime import datetime

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.container import BarContainer

# %% [markdown]
# ## Parameters
#
# Set the paths to the metrics files and the new pipeline name.

# %%
# -----------------------
# Input parameters
# -----------------------

# Path to the gene metrics TSV from pipeline_qc
gene_metrics_path = "/cellar/users/aklie/data/datasets/tf_perturb_seq/scratch/2026_01_21/Hon_WTC11-cardiomyocyte-differentiation_TF-Perturb-seq/results/mapping_gene/gene_metrics.tsv"

# Path to the guide metrics TSV from pipeline_qc
guide_metrics_path = "/cellar/users/aklie/data/datasets/tf_perturb_seq/scratch/2026_01_21/Hon_WTC11-cardiomyocyte-differentiation_TF-Perturb-seq/results/mapping_guide/guide_metrics.tsv"

# Name for the new pipeline entry (e.g., "CRISPR Pipeline v0.0.4 (02/04/2026)")
new_pipeline_name = "CRISPR Pipeline v0.0.4 (02/05/2026)"

# Path to the existing tracker TSV
tracker_path = "/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/production_TF-Perturb-seq/2026_02_05_pipeline_comparison.tsv"

# Whether to run the plotting code after updating
run_plots = True

# %% [markdown]
# ## Load and Update Tracker

# %%
# -----------------------
# Load metrics files
# -----------------------
gene_df = pd.read_csv(gene_metrics_path, sep="\t")
guide_df = pd.read_csv(guide_metrics_path, sep="\t")

# Filter out the "all" row - we only want per-lane metrics
gene_df = gene_df[gene_df["batch"] != "all"].copy()
guide_df = guide_df[guide_df["batch"] != "all"].copy()

print(f"Gene metrics lanes: {gene_df['batch'].tolist()}")
print(f"Guide metrics lanes: {guide_df['batch'].tolist()}")
# Out:
# Gene metrics lanes: ['IGVFDS0119GHBM', 'IGVFDS0814DYDR', 'IGVFDS0860HOHE', 'IGVFDS1042ITOF', 'IGVFDS1584ZJUM', 'IGVFDS1867JBBD', 'IGVFDS2653YSTF', 'IGVFDS2933CBPV', 'IGVFDS3275TXAD', 'IGVFDS3599AKSM', 'IGVFDS4080NNVH', 'IGVFDS5151YCLI', 'IGVFDS5304ZOXD', 'IGVFDS5398VEFY', 'IGVFDS6472JBHY', 'IGVFDS6688BORQ', 'IGVFDS6847GSEQ', 'IGVFDS6980CXOR', 'IGVFDS6990PWDJ', 'IGVFDS7181KBXZ', 'IGVFDS7696ONVJ', 'IGVFDS8493OWMF', 'IGVFDS8548HJBX', 'IGVFDS9367JFNB', 'IGVFDS9568EYXJ', 'IGVFDS9699UXJW']
# Guide metrics lanes: ['IGVFDS0119GHBM', 'IGVFDS0814DYDR', 'IGVFDS0860HOHE', 'IGVFDS1042ITOF', 'IGVFDS1584ZJUM', 'IGVFDS1867JBBD', 'IGVFDS2653YSTF', 'IGVFDS2933CBPV', 'IGVFDS3275TXAD', 'IGVFDS3599AKSM', 'IGVFDS4080NNVH', 'IGVFDS5151YCLI', 'IGVFDS5304ZOXD', 'IGVFDS5398VEFY', 'IGVFDS6472JBHY', 'IGVFDS6688BORQ', 'IGVFDS6847GSEQ', 'IGVFDS6980CXOR', 'IGVFDS6990PWDJ', 'IGVFDS7181KBXZ', 'IGVFDS7696ONVJ', 'IGVFDS8493OWMF', 'IGVFDS8548HJBX', 'IGVFDS9367JFNB', 'IGVFDS9568EYXJ', 'IGVFDS9699UXJW']

# %%
# -----------------------
# Build new rows from metrics
# -----------------------

# Merge gene and guide metrics on batch (lane)
merged = gene_df.merge(guide_df, on="batch", suffixes=("_gene", "_guide"))

# Create new rows matching tracker format
new_rows = []
for _, row in merged.iterrows():
    new_rows.append({
        "Lane": row["batch"],
        "Pipeline": new_pipeline_name,
        "Median Tx UMIs/cell": int(round(row["umi_median"])),
        "Median sgRNA UMIs/cell": int(round(row["guide_umi_median"])),
        "Singlets w/ sgRNA UMIs > 0": int(row["n_cells_with_guide"]),
        "Mean assigned sgRNA/cell": round(row["guides_per_cell_mean"], 2),
        "Singlets w/ exactly 1 sgRNA assigned": int(row["n_cells_exactly_1_guide"]),
    })

new_rows_df = pd.DataFrame(new_rows)
print(f"New rows to add ({len(new_rows_df)} lanes):")
new_rows_df
# Out:
# New rows to add (26 lanes):
#               Lane                             Pipeline  Median Tx UMIs/cell  \
# 0   IGVFDS0119GHBM  CRISPR Pipeline v0.0.4 (02/05/2026)                 2871
# 1   IGVFDS0814DYDR  CRISPR Pipeline v0.0.4 (02/05/2026)                 3290
# 2   IGVFDS0860HOHE  CRISPR Pipeline v0.0.4 (02/05/2026)                 2826
# 3   IGVFDS1042ITOF  CRISPR Pipeline v0.0.4 (02/05/2026)                 2546
# 4   IGVFDS1584ZJUM  CRISPR Pipeline v0.0.4 (02/05/2026)                 3078
# 5   IGVFDS1867JBBD  CRISPR Pipeline v0.0.4 (02/05/2026)                 2775
# 6   IGVFDS2653YSTF  CRISPR Pipeline v0.0.4 (02/05/2026)                 2064
# 7   IGVFDS2933CBPV  CRISPR Pipeline v0.0.4 (02/05/2026)                 2538
# 8   IGVFDS3275TXAD  CRISPR Pipeline v0.0.4 (02/05/2026)                 2254
# 9   IGVFDS3599AKSM  CRISPR Pipeline v0.0.4 (02/05/2026)                 2915
# 10  IGVFDS4080NNVH  CRISPR Pipeline v0.0.4 (02/05/2026)                 2571
# 11  IGVFDS5151YCLI  CRISPR Pipeline v0.0.4 (02/05/2026)                 2561
# 12  IGVFDS5304ZOXD  CRISPR Pipeline v0.0.4 (02/05/2026)                 2791
# 13  IGVFDS5398VEFY  CRISPR Pipeline v0.0.4 (02/05/2026)                 1743
# 14  IGVFDS6472JBHY  CRISPR Pipeline v0.0.4 (02/05/2026)                 2905
# 15  IGVFDS6688BORQ  CRISPR Pipeline v0.0.4 (02/05/2026)                 2496
# 16  IGVFDS6847GSEQ  CRISPR Pipeline v0.0.4 (02/05/2026)                 2907
# 17  IGVFDS6980CXOR  CRISPR Pipeline v0.0.4 (02/05/2026)                 2482
# 18  IGVFDS6990PWDJ  CRISPR Pipeline v0.0.4 (02/05/2026)                 2637
# 19  IGVFDS7181KBXZ  CRISPR Pipeline v0.0.4 (02/05/2026)                 2384
# 20  IGVFDS7696ONVJ  CRISPR Pipeline v0.0.4 (02/05/2026)                 3147
# 21  IGVFDS8493OWMF  CRISPR Pipeline v0.0.4 (02/05/2026)                 2654
# 22  IGVFDS8548HJBX  CRISPR Pipeline v0.0.4 (02/05/2026)                 2864
# 23  IGVFDS9367JFNB  CRISPR Pipeline v0.0.4 (02/05/2026)                 2259
# 24  IGVFDS9568EYXJ  CRISPR Pipeline v0.0.4 (02/05/2026)                 3026
# 25  IGVFDS9699UXJW  CRISPR Pipeline v0.0.4 (02/05/2026)                 2892
#
#     Median sgRNA UMIs/cell  Singlets w/ sgRNA UMIs > 0  \
# 0                      668                       28624
# 1                      844                       33390
# 2                      799                       35843
# 3                      739                       34354
# 4                      912                       34715
# 5                      987                       34033
# 6                      304                       32602
# 7                      861                       33292
# 8                     1099                       30909
# 9                     1028                       34980
# 10                    1022                       27858
# 11                     409                       33689
# 12                     850                       28806
# 13                     724                       36039
# 14                     934                       33502
# 15                     574                       30495
# 16                    1084                       33831
# 17                     931                       31628
# 18                    1051                       33875
# 19                     858                       34921
# 20                     870                       31882
# 21                    1049                       31239
# 22                    1066                       34167
# 23                     397                       35746
# 24                     844                       34233
# 25                     879                       33702
#
#     Mean assigned sgRNA/cell  Singlets w/ exactly 1 sgRNA assigned
# 0                       7.18                                   799
# 1                       5.54                                   691
# 2                       5.32                                  1013
# 3                       4.92                                  1118
# 4                       5.61                                   762
# 5                       6.17                                   525
# 6                       4.97                                  2704
# 7                       5.31                                   865
# 8                       6.32                                   464
# 9                       6.67                                   469
# 10                      7.04                                   391
# 11                      6.15                                  1837
# 12                      7.52                                   535
# 13                      5.38                                   816
# 14                      6.11                                   497
# 15                      6.83                                  1103
# 16                      6.89                                   441
# 17                      6.19                                   467
# 18                      6.69                                   461
# 19                      6.00                                   533
# 20                      5.66                                   612
# 21                      5.63                                   634
# 22                      6.44                                   551
# 23                      5.36                                  2216
# 24                      5.52                                   793
# 25                      5.67                                   691

# %%
# -----------------------
# Load existing tracker and append new rows
# -----------------------
tracker_df = pd.read_csv(tracker_path, sep="\t")
print(f"Existing tracker has {len(tracker_df)} rows")

# Check if this pipeline already exists
if new_pipeline_name in tracker_df["Pipeline"].values:
    print(f"WARNING: Pipeline '{new_pipeline_name}' already exists in tracker!")
    print("Existing rows will be replaced.")
    tracker_df = tracker_df[tracker_df["Pipeline"] != new_pipeline_name]

# Append new rows
updated_df = pd.concat([tracker_df, new_rows_df], ignore_index=True)
print(f"Updated tracker has {len(updated_df)} rows")
# Out:
# Existing tracker has 28 rows
# Updated tracker has 54 rows

# %%
# -----------------------
# Save updated tracker with new date
# -----------------------
tracker_dir = os.path.dirname(tracker_path)
today_str = datetime.now().strftime("%Y_%m_%d")
new_tracker_path = os.path.join(tracker_dir, f"{today_str}_pipeline_comparison.tsv")

updated_df.to_csv(new_tracker_path, sep="\t", index=False)
print(f"Saved updated tracker to: {new_tracker_path}")

# Display final table
updated_df
# Out:
# Saved updated tracker to: /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/production_TF-Perturb-seq/2026_02_05_pipeline_comparison.tsv
#               Lane                             Pipeline Median Tx UMIs/cell  \
# 0   IGVFDS6239SWYS                     Hon Lab Internal               3,563
# 1   IGVFDS8747AVMA                     Hon Lab Internal               3,948
# 2   IGVFDS8493OWMF                     Hon Lab Internal               3,491
# 3   IGVFDS3275TXAD                     Hon Lab Internal               2,983
# 4   IGVFDS2933CBPV                     Hon Lab Internal               3,517
# 5   IGVFDS7181KBXZ                     Hon Lab Internal               3,296
# 6   IGVFDS5398VEFY                     Hon Lab Internal               2,374
# 7   IGVFDS0119GHBM                     Hon Lab Internal               3,852
# 8   IGVFDS5304ZOXD                     Hon Lab Internal               3,765
# 9   IGVFDS4080NNVH                     Hon Lab Internal               3,434
# 10  IGVFDS6688BORQ                     Hon Lab Internal               3,512
# 11  IGVFDS5151YCLI                     Hon Lab Internal               3,676
# 12  IGVFDS2653YSTF                     Hon Lab Internal               3,357
# 13  IGVFDS9367JFNB                     Hon Lab Internal               3,345
# 14  IGVFDS6472JBHY                     Hon Lab Internal               3,738
# 15  IGVFDS1042ITOF                     Hon Lab Internal               3,254
# 16  IGVFDS9699UXJW                     Hon Lab Internal               3,747
# 17  IGVFDS1867JBBD                     Hon Lab Internal               3,576
# 18  IGVFDS6980CXOR                     Hon Lab Internal               3,287
# 19  IGVFDS7696ONVJ                     Hon Lab Internal               4,148
# 20  IGVFDS0814DYDR                     Hon Lab Internal               4,222
# 21  IGVFDS6990PWDJ                     Hon Lab Internal               3,378
# 22  IGVFDS1584ZJUM                     Hon Lab Internal               3,956
# 23  IGVFDS6847GSEQ                     Hon Lab Internal               3,812
# 24  IGVFDS3599AKSM                     Hon Lab Internal               3,787
# 25  IGVFDS8548HJBX                     Hon Lab Internal               3,661
# 26  IGVFDS9568EYXJ                     Hon Lab Internal               4,044
# 27  IGVFDS0860HOHE                     Hon Lab Internal               3,730
# 28  IGVFDS0119GHBM  CRISPR Pipeline v0.0.4 (02/05/2026)                2871
# 29  IGVFDS0814DYDR  CRISPR Pipeline v0.0.4 (02/05/2026)                3290
# 30  IGVFDS0860HOHE  CRISPR Pipeline v0.0.4 (02/05/2026)                2826
# 31  IGVFDS1042ITOF  CRISPR Pipeline v0.0.4 (02/05/2026)                2546
# 32  IGVFDS1584ZJUM  CRISPR Pipeline v0.0.4 (02/05/2026)                3078
# 33  IGVFDS1867JBBD  CRISPR Pipeline v0.0.4 (02/05/2026)                2775
# 34  IGVFDS2653YSTF  CRISPR Pipeline v0.0.4 (02/05/2026)                2064
# 35  IGVFDS2933CBPV  CRISPR Pipeline v0.0.4 (02/05/2026)                2538
# 36  IGVFDS3275TXAD  CRISPR Pipeline v0.0.4 (02/05/2026)                2254
# 37  IGVFDS3599AKSM  CRISPR Pipeline v0.0.4 (02/05/2026)                2915
# 38  IGVFDS4080NNVH  CRISPR Pipeline v0.0.4 (02/05/2026)                2571
# 39  IGVFDS5151YCLI  CRISPR Pipeline v0.0.4 (02/05/2026)                2561
# 40  IGVFDS5304ZOXD  CRISPR Pipeline v0.0.4 (02/05/2026)                2791
# 41  IGVFDS5398VEFY  CRISPR Pipeline v0.0.4 (02/05/2026)                1743
# 42  IGVFDS6472JBHY  CRISPR Pipeline v0.0.4 (02/05/2026)                2905
# 43  IGVFDS6688BORQ  CRISPR Pipeline v0.0.4 (02/05/2026)                2496
# 44  IGVFDS6847GSEQ  CRISPR Pipeline v0.0.4 (02/05/2026)                2907
# 45  IGVFDS6980CXOR  CRISPR Pipeline v0.0.4 (02/05/2026)                2482
# 46  IGVFDS6990PWDJ  CRISPR Pipeline v0.0.4 (02/05/2026)                2637
# 47  IGVFDS7181KBXZ  CRISPR Pipeline v0.0.4 (02/05/2026)                2384
# 48  IGVFDS7696ONVJ  CRISPR Pipeline v0.0.4 (02/05/2026)                3147
# 49  IGVFDS8493OWMF  CRISPR Pipeline v0.0.4 (02/05/2026)                2654
# 50  IGVFDS8548HJBX  CRISPR Pipeline v0.0.4 (02/05/2026)                2864
# 51  IGVFDS9367JFNB  CRISPR Pipeline v0.0.4 (02/05/2026)                2259
# 52  IGVFDS9568EYXJ  CRISPR Pipeline v0.0.4 (02/05/2026)                3026
# 53  IGVFDS9699UXJW  CRISPR Pipeline v0.0.4 (02/05/2026)                2892
#
#    Median sgRNA UMIs/cell Singlets w/ sgRNA UMIs > 0  \
# 0                   1,001                     24,965
# 1                   1,198                     26,881
# 2                   1,245                     27,596
# 3                   1,311                     27,143
# 4                   1,086                     28,632
# 5                   1,074                     30,023
# 6                     874                     31,651
# 7                     797                     23,150
# 8                   1,014                     24,141
# 9                   1,254                     24,801
# 10                    701                     24,307
# 11                    511                     25,661
# 12                    432                     22,486
# 13                    518                     27,866
# 14                  1,101                     28,742
# 15                    848                     28,655
# 16                  1,025                     28,103
# 17                  1,139                     28,352
# 18                  1,139                     27,037
# 19                  1,053                     26,967
# 20                  1,004                     28,480
# 21                  1,181                     28,279
# 22                  1,049                     28,734
# 23                  1,241                     27,792
# 24                  1,186                     29,113
# 25                  1,207                     28,088
# 26                    996                     27,762
# 27                    936                     29,944
# 28                    668                      28624
# 29                    844                      33390
# 30                    799                      35843
# 31                    739                      34354
# 32                    912                      34715
# 33                    987                      34033
# 34                    304                      32602
# 35                    861                      33292
# 36                   1099                      30909
# 37                   1028                      34980
# 38                   1022                      27858
# 39                    409                      33689
# 40                    850                      28806
# 41                    724                      36039
# 42                    934                      33502
# 43                    574                      30495
# 44                   1084                      33831
# 45                    931                      31628
# 46                   1051                      33875
# 47                    858                      34921
# 48                    870                      31882
# 49                   1049                      31239
# 50                   1066                      34167
# 51                    397                      35746
# 52                    844                      34233
# 53                    879                      33702
#
#     Mean assigned sgRNA/cell Singlets w/ exactly 1 sgRNA assigned
# 0                       1.93                               10,895
# 1                       1.95                               11,460
# 2                       1.98                               11,617
# 3                       1.99                               11,388
# 4                       1.96                               12,106
# 5                       1.95                               12,854
# 6                       1.91                               13,967
# 7                       1.80                               11,640
# 8                       1.83                               11,503
# 9                       1.93                               10,820
# 10                      1.80                               12,066
# 11                      1.75                               13,514
# 12                      1.73                               12,030
# 13                      1.78                               14,120
# 14                      1.92                               12,552
# 15                      1.90                               12,829
# 16                      1.90                               12,384
# 17                      1.93                               12,349
# 18                      1.93                               11,742
# 19                      1.91                               11,865
# 20                      1.92                               12,514
# 21                      1.92                               12,415
# 22                      1.92                               12,623
# 23                      1.93                               12,088
# 24                      1.93                               12,702
# 25                      1.91                               12,459
# 26                      1.91                               12,315
# 27                      1.91                               13,310
# 28                      7.18                                  799
# 29                      5.54                                  691
# 30                      5.32                                 1013
# 31                      4.92                                 1118
# 32                      5.61                                  762
# 33                      6.17                                  525
# 34                      4.97                                 2704
# 35                      5.31                                  865
# 36                      6.32                                  464
# 37                      6.67                                  469
# 38                      7.04                                  391
# 39                      6.15                                 1837
# 40                      7.52                                  535
# 41                      5.38                                  816
# 42                      6.11                                  497
# 43                      6.83                                 1103
# 44                      6.89                                  441
# 45                      6.19                                  467
# 46                      6.69                                  461
# 47                      6.00                                  533
# 48                      5.66                                  612
# 49                      5.63                                  634
# 50                      6.44                                  551
# 51                      5.36                                 2216
# 52                      5.52                                  793
# 53                      5.67                                  691

# %% [markdown]
# ## Comparison Plots
#
# Generate faceted bar plots comparing metrics across pipelines.

# %%
# Load /cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/production_TF-Perturb-seq/2026_02_05_pipeline_comparison.tsv
updated_df = pd.read_csv("/cellar/users/aklie/data/datasets/tf_perturb_seq/datasets/production_TF-Perturb-seq/2026_02_05_pipeline_comparison.tsv", sep="\t")

# %%
if not run_plots:
    print("Skipping plots (run_plots=False)")
else:
    # -----------------------
    # Lane order + colors
    # -----------------------
    lane_order = [
        "IGVFDS6239SWYS", "IGVFDS8747AVMA", "IGVFDS8493OWMF", "IGVFDS3275TXAD",
        "IGVFDS2933CBPV", "IGVFDS7181KBXZ", "IGVFDS5398VEFY", "IGVFDS0119GHBM",
        "IGVFDS5304ZOXD", "IGVFDS4080NNVH", "IGVFDS6688BORQ", "IGVFDS5151YCLI",
        "IGVFDS2653YSTF", "IGVFDS9367JFNB", "IGVFDS6472JBHY", "IGVFDS1042ITOF",
        "IGVFDS9699UXJW", "IGVFDS1867JBBD", "IGVFDS6980CXOR", "IGVFDS7696ONVJ",
        "IGVFDS0814DYDR", "IGVFDS6990PWDJ", "IGVFDS1584ZJUM", "IGVFDS6847GSEQ",
        "IGVFDS3599AKSM", "IGVFDS8548HJBX", "IGVFDS9568EYXJ", "IGVFDS0860HOHE",
    ]
    lane_colors = {
        "IGVFDS6239SWYS": "#1f77b4",
        "IGVFDS8747AVMA": "#ff7f0e",
        "IGVFDS8493OWMF": "#2ca02c",
        "IGVFDS3275TXAD": "#d62728",
        "IGVFDS2933CBPV": "#9467bd",
        "IGVFDS7181KBXZ": "#8c564b",
        "IGVFDS5398VEFY": "#e377c2",
        "IGVFDS0119GHBM": "#7f7f7f",
        "IGVFDS5304ZOXD": "#bcbd22",
        "IGVFDS4080NNVH": "#17becf",
        "IGVFDS6688BORQ": "#aec7e8",
        "IGVFDS5151YCLI": "#ffbb78",
        "IGVFDS2653YSTF": "#98df8a",
        "IGVFDS9367JFNB": "#ff9896",
        "IGVFDS6472JBHY": "#c5b0d5",
        "IGVFDS1042ITOF": "#c49c94",
        "IGVFDS9699UXJW": "#f7b6d2",
        "IGVFDS1867JBBD": "#c7c7c7",
        "IGVFDS6980CXOR": "#dbdb8d",
        "IGVFDS7696ONVJ": "#9edae5",
        "IGVFDS0814DYDR": "#393b79",
        "IGVFDS6990PWDJ": "#637939",
        "IGVFDS1584ZJUM": "#8c6d31",
        "IGVFDS6847GSEQ": "#843c39",
        "IGVFDS3599AKSM": "#7b4173",
        "IGVFDS8548HJBX": "#5254a3",
        "IGVFDS9568EYXJ": "#6b6ecf",
        "IGVFDS0860HOHE": "#b5cf6b",
    }

# %%
if run_plots:
    # -----------------------
    # Prepare data for plotting
    # -----------------------
    wide = updated_df.rename(columns={
        "Lane": "lane",
        "Pipeline": "pipeline",
        "Median Tx UMIs/cell": "median_txn_umi_per_cell",
        "Median sgRNA UMIs/cell": "median_sgrna_umi_per_cell",
        "Singlets w/ sgRNA UMIs > 0": "gt0_sgrna",
        "Mean assigned sgRNA/cell": "mean_sgrna_per_cell",
        "Singlets w/ exactly 1 sgRNA assigned": "exactly1_sgrna",
    })

    # ensure numeric cols are numeric
    numeric_cols = [c for c in wide.columns if c not in ["lane", "pipeline"]]
    for c in numeric_cols:
        wide[c] = pd.to_numeric(wide[c], errors="coerce")

    # Metrics to facet
    metrics_to_plot = [
        "median_txn_umi_per_cell",
        "median_sgrna_umi_per_cell",
        "gt0_sgrna",
        "mean_sgrna_per_cell",
        "exactly1_sgrna",
    ]

    metric_labels = {
        "median_txn_umi_per_cell": "Median Tx UMIs/cell",
        "median_sgrna_umi_per_cell": "Median sgRNA UMIs/cell",
        "gt0_sgrna": "Singlets w/ sgRNA UMIs > 0",
        "mean_sgrna_per_cell": "Mean assigned sgRNA/cell",
        "exactly1_sgrna": "Singlets w/ exactly 1 sgRNA assigned",
    }

    df = wide.melt(
        id_vars=["lane", "pipeline"],
        value_vars=metrics_to_plot,
        var_name="metric",
        value_name="value",
    )
    df["metric"] = df["metric"].map(metric_labels)

    # Pipeline order + hatches (dynamically build from data)
    pipeline_order = wide["pipeline"].unique().tolist()
    
    # Predefined hatches, cycle if needed
    hatch_patterns = ["", "\\\\", "xx", "++", "//", "..", "oo", "**"]
    pipeline_hatches = {p: hatch_patterns[i % len(hatch_patterns)] for i, p in enumerate(pipeline_order)}
    
    print(f"Pipelines in order: {pipeline_order}")
# Out:
# Pipelines in order: ['Hon Lab Internal', 'CRISPR Pipeline v0.0.4 (02/05/2026)']

# %%
if run_plots:
    # -----------------------
    # Presentation-ish params
    # -----------------------
    plt.rcParams.update({
        "font.size": 16,
        "axes.titlesize": 24,
        "axes.labelsize": 24,
        "xtick.labelsize": 14,
        "ytick.labelsize": 14,
        "legend.fontsize": 14,
    })
    sns.set(style="white")

    # -----------------------
    # Custom barplot: lane colors + pipeline hatches
    # -----------------------
    def barplot_with_lane_color_and_pipeline_hatch(data, x, y, hue, **kwargs):
        ax = plt.gca()

        sns.barplot(
            data=data,
            x=x,
            y=y,
            hue=hue,
            order=lane_order,
            hue_order=pipeline_order,
            dodge=True,
            edgecolor="black",
            **kwargs
        )

        # only bar containers (ignore errorbar containers)
        bar_containers = [c for c in ax.containers if isinstance(c, BarContainer)]

        # each container corresponds to one hue (pipeline), in hue_order
        for p_idx, container in enumerate(bar_containers):
            if p_idx >= len(pipeline_order):
                continue
            pipeline = pipeline_order[p_idx]

            for i, patch in enumerate(container.patches):
                if i >= len(lane_order):
                    continue
                lane = lane_order[i]
                patch.set_facecolor(lane_colors[lane])
                patch.set_hatch(pipeline_hatches[pipeline])

    # -----------------------
    # FacetGrid
    # -----------------------
    g = sns.FacetGrid(
        df,
        col="metric",
        col_wrap=3,
        sharey=False,
        height=4
    )

    g.map_dataframe(
        barplot_with_lane_color_and_pipeline_hatch,
        x="lane",
        y="value",
        hue="pipeline"
    )

    # axis cleanup
    for ax in g.axes.flatten():
        ax.set_xlabel("")
        ax.set_ylabel("")
        ax.tick_params(axis="x", rotation=90)

    # remove per-axis legends
    for ax in g.axes.flatten():
        leg = ax.get_legend()
        if leg is not None:
            leg.remove()

    # -----------------------
    # Legends: pipelines (hatch) + lanes (color)
    # -----------------------
    pipeline_handles = [
        Patch(facecolor="white", edgecolor="black", hatch=pipeline_hatches[p], label=p)
        for p in pipeline_order
    ]
    lane_handles = [
        Patch(facecolor=lane_colors[l], edgecolor="black", label=l)
        for l in lane_order
    ]
    all_handles = pipeline_handles + lane_handles

    g.fig.legend(
        handles=all_handles,
        loc="lower right",
        bbox_to_anchor=(0.98, 0.02),
        borderaxespad=0.5
    )

    g.set_titles("{col_name}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # DONE!

# %% [markdown]
# ---
